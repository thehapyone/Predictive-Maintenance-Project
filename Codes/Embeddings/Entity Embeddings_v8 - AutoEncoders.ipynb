# %% [markdown]
# # Learned Embeddings - AutoEncoders
# This program will attempt to create embeddings for the categorical features using the pipelines code developed.

# %% [markdown]
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-connect-button").shadowRoot.getElementById('connect').click()
# }
# setInterval(ClickConnect,60000)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import copy as copy
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import sys
sys.path.append('drive/My Drive/Thesis/Collab Notebooks/')

# %%
#%run drive/"My Drive"/Thesis/"Collab Notebooks"/category_pipeline.ipynb
#%load

# %%
# using the latest updated file
data = pd.read_csv("drive/My Drive/Thesis/data/Data_Engineering/Edited_Raw_Data/v5_Sorted_Raw_Db_with_RUL_imputed.csv", sep=',', low_memory=False)
#data = pd.read_csv("drive/My Drive/Thesis/data/Feature_Engineering/KNN_Imputed_Datasets/KNN_Imputed_k_40.csv", sep=',', low_memory=False)
#data = pd.read_csv("drive/My Drive/Thesis/data/Data_Engineering/Edited_Raw_Data/v2_Sorted_Database.csv", sep=',', low_memory=False)
data2 = pd.read_csv("drive/My Drive/Thesis/data/Embedding_Data/v2_sorted_data_new.csv", sep=',', low_memory=False)

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Pipeline Extraction

# %%
# Applying the Extraction pipeline
# first stage of the pipeline
from extraction_pipeline import *
from category_pipeline import *

# %%
'''
# remove duplicates
#data = removeDuplicates(data, debug=True)
data = data.drop(labels=['DELIVERY_DATE.1'], axis=1)
print ('After duplicates removal - ',data.shape)

# the only duplicate column discovered was - ['DELIVERY_DATE.1']
print ('After duplicates removal - ',data.shape)
# Remove zero variance
data = removeZeroVariance(data, debug=True)
print ('After Zero Variance removal - ',data.shape)
'''
# drop redundant features
#data = dropRedundantFeatures(data)
print ('After Redundant Drop removal - ',data.shape)
# Out:
# After Redundant Drop removal -  (19954, 447)

# %%
# date extractor
# data = dateInfoExtractor(raw_data=data, debug=False)
print ('After date extractor - ',data.shape)
# Out:
# After date extractor -  (19954, 447)

# %%
# missing values analysis
#
print ("missing values rate before: ", 100 * (data.isnull().sum().sort_values(ascending=False) / data.shape[0]) )
#data = fillMissingValues(data)
print ("missing values rate after: ", 100 * (data.isnull().sum().sort_values(ascending=False) / data.shape[0]) )
# Out:
# missing values rate before:  VFE_0007_CAB_HEIGHT                                 0.0
# LX_PSC_P1E0Q_TOTAL_NUMBER_OF_AUTOMATIC_PARK         0.0
# LX_PSC_P1ATN_MAIN_LOG_VTC_ENGINE_SPEED_FUEL         0.0
# LX_PSC_P1ATO_MAIN_LOG_TOTAL_ENERGY                  0.0
# LX_PSC_P1BB0_TOTAL_ENGINE_TIME                      0.0
# LX_PSC_P1BBV_DISTANCE_IN_TOP_GEAR                   0.0
# LX_PSC_P1BBW_FUEL_IN_TOP_GEAR                       0.0
# LX_PSC_P1BBX_TIME_IN_TOP_GEAR                       0.0
# LX_PSC_P1BBZ_TOTAL_ENGINE_REVOLUTIONS               0.0
# LX_PSC_P1C5K_BRAKING_WITH_BIG_DECELERATION          0.0
# LX_PSC_P1E0N_TOTAL_NUMBER_OF_PARK_BRAKE_MAN         0.0
# LX_PSC_P1E0O_TOTAL_NUMBER_OF_PARK_BRAKE_MAN         0.0
# LX_PSC_P1E0P_TOTAL_NUMBER_OF_AUTOMATIC_PARK         0.0
# LX_PSC_P1E8Y_TOTAL_NUMBER_OF_PARK_BRAKE_APP         0.0
# LX_PSC_P1ATL_MAIN_LOG_PEDAL_FUEL                    0.0
# LX_PSC_P1EVS_CLUTCH_PLATE_WEAR                      0.0
# LX_PSC_P1FUN_NUMBER_OF_ENGINE_STARTS_DURING         0.0
# LX_PSC_P1FUO_NUMBER_OF_STARTER_ACTIVATION_D         0.0
# LX_PSC_P1FXC_UREA_SYSTEM_ERROR_COUNT_LOG            0.0
# LX_PSC_P1FXD_TIME_WITH_UREA_SYSTEM_ERROR_LO         0.0
# LX_PSC_P1FY7_TOP_GEAR_1_MODE_TOTAL_DISTANCE         0.0
# LX_PSC_P1FY8_TOP_GEAR_1_MODE_TOTAL_FUEL             0.0
# LX_PSC_P1FY9_TOP_GEAR_1_MODE_TOTAL_TIME             0.0
# LX_PSC_P1FYO_TOTAL_TIME_IN_IDLE_MODE_PTO            0.0
# LX_PSC_P1I80_TOP_VALUE_OF_ENGINE_SPEED_IN_O         0.0
# LX_PSC_P1IPV_INJECTED_UREA_TOTAL_MASS               0.0
# LX_PSC_P1ATM_MAIN_LOG_ROAD_SPEED_LIMIT_FUEL         0.0
# LX_PSC_P1ATK_MAIN_LOG_ECONOMICAL_FUEL               0.0
# LX_PSC_P1IT0_AFTERTREATMENT_REGENERATION_IN         0.0
# LX_PSC_P1ASU_MAIN_LOG_DRIVE_FUEL                    0.0
# LX_PSC_P1AS4_MAIN_LOG_ECON_DISTANCE                 0.0
# LX_PSC_P1AS5_MAIN_LOG_PEDAL_DISTANCE                0.0
# LX_PSC_P1AS6_MAIN_LOG_PTO_DISTANCE                  0.0
# LX_PSC_P1AS7_MAIN_LOG_ROAD_SPEED_LIMIT_DIST         0.0
# LX_PSC_P1AS9_MAIN_LOG_BRAKE_TIME                    0.0
# LX_PSC_P1ASH_COOLANT_PUMP_NUMBER_OF_ACTIVAT         0.0
# LX_PSC_P1ASI_COOLANT_PUMP_ACTIVATION_TIME           0.0
# LX_PSC_P1ASP_MAIN_LOG_CRUISE_DISTANCE               0.0
# LX_PSC_P1ASQ_MAIN_LOG_CRUISE_FUEL                   0.0
# LX_PSC_P1ASR_MAIN_LOG_CRUISE_TIME                   0.0
# LX_PSC_P1AST_MAIN_LOG_DRIVE_DISTANCE                0.0
# LX_PSC_P1ASV_MAIN_LOG_DRIVE_TIME                    0.0
# LX_PSC_P1ATJ_MAIN_LOG_VTC_ENGINE_SPEED_TIME         0.0
# LX_PSC_P1ASW_MAIN_LOG_IDLE_FUEL                     0.0
# LX_PSC_P1ASX_MAIN_LOG_PTO_FUEL                      0.0
# LX_PSC_P1ATA_MAIN_LOG_COASTING_TIME                 0.0
# LX_PSC_P1ATB_MAIN_LOG_CUSTOMER_ENGINE_SPEED         0.0
# LX_PSC_P1ATC_MAIN_LOG_CUSTOMER_VEHICLE_SPEE         0.0
# LX_PSC_P1ATD_MAIN_LOG_ECONOMICAL_TIME               0.0
# LX_PSC_P1ATE_MAIN_LOG_IDLE_TIME                     0.0
# LX_PSC_P1ATF_MAIN_LOG_KEY_ON_TIME                   0.0
# LX_PSC_P1ATG_MAIN_LOG_PEDAL_TIME                    0.0
# LX_PSC_P1ATH_MAIN_LOG_PTO_TIME                      0.0
# LX_PSC_P1ATI_MAIN_LOG_ROAD_SPEED_LIMIT_TIME         0.0
# LX_PSC_P1IPX_TOTAL_INJECTED_UREA__L                 0.0
# LX_PSC_P1IT1_AFTERTREATMENT_REGENERATION_IN         0.0
# LX_PSC_P1AS2_MAIN_LOG_BRAKE_DISTANCE                0.0
# LX_PST_P1H6B_137_NCATCOMP                           0.0
# LX_PST_P1E0L_1072_MV3                               0.0
# LX_PST_P1E0L_1073_MV4                               0.0
# LX_PST_P1E0L_1074_MV5                               0.0
# LX_PST_P1E1E_812_TAV_COMP                           0.0
# LX_PST_P1E1E_813_OPERATION_TIME                     0.0
# LX_PST_P1EM9_11_PMAIRDRYERCARTRIDGERESETCALEND      0.0
# LX_PST_P1EM9_12_PMAIRDRYERCARTRIDGERESETVEHICL      0.0
# LX_PST_P1EM9_13_PMAIRDRYERCARTRIDGERESETENGINE      0.0
# LX_PST_P1H6B_133_OBDCOND                            0.0
# LX_PST_P1H6B_134_IGNCNTR                            0.0
# LX_PST_P1H6B_136_HCCATCOND                          0.0
# LX_PST_P1H6B_138_NCATCOND                           0.0
# LX_PST_P1C3B_127_VDLOVERSPEEDDISTANCE_LOG           0.0
# LX_PST_P1H6B_141_PMCOMP                             0.0
# LX_PST_P1H6B_142_PMCOND                             0.0
# LX_PST_P1H6B_143_EGSCOMP                            0.0
# LX_PST_P1H6B_144_EGSCOND                            0.0
# LX_PST_P1H6B_145_EGRCOMP                            0.0
# LX_PST_P1H6B_146_EGRCOND                            0.0
# LX_PST_P1H6B_147_BPCOMP                             0.0
# LX_PST_P1H6B_148_BPCOND                             0.0
# LX_PST_P1H6B_149_FUELCOMP                           0.0
# LX_PST_P1H6B_150_FUELCOND                           0.0
# LX_TOTAL_VEHICLE_DISTANCE_RULE_BASED                0.0
# LX_PST_P1C3B_129_VDLOVERSPEEDMAX_LOG                0.0
# LX_PST_P1C3B_126_VDLOVERSPEEDFUEL_LOG               0.0
# LX_PSC_P1ITX_FUEL_CONSUMPTION_DURING_MOVING         0.0
# LX_PST_P1B3C_62_ELENGINEGREENAREATIME_LOG           0.0
# LX_PSC_P1IV0_AIR_PRODUCTION_MODULATOR_HEATE         0.0
# LX_PSC_P1J63_ELECTRONIC_STABILITY_PROGRAMES         0.0
# LX_PSC_P1J65_BRAKE_ASSIST_DATA                      0.0
# LX_PSC_P1JR3_AUTOMATIC_SULPHUR_FUEL_REGENER         0.0
# LX_PSC_P1MNF_COMPRESSOR_LOAD_PHASE_COUNTER          0.0
# LX_PST_P1B2W_87_ELLOWIDLESPEEDVEHICLESTOPPEDTI      0.0
# LX_PST_P1B2W_88_ELLOWIDLESPEEDVEHICLESTOPPEDFU      0.0
# LX_PST_P1B3A_2156_BCLVEHICLEMODEACCESSORYTIME_LO    0.0
# LX_PST_P1B3A_329_BCLVEHICLEMODELIVINGTIME_LOG       0.0
# LX_PST_P1B3A_331_BCLVEHICLEMODEPRERUNNINGTIME_L     0.0
# LX_PST_P1B3A_332_BCLVEHICLEMODECRANKINGTIME_LOG     0.0
# LX_PST_P1B3C_63_ELENGINEGREENAREAFUEL_LOG           0.0
# LX_PST_P1C3B_125_VDLOVERSPEEDTIME_LOG               0.0
# LX_PST_P1B3C_64_ELENGINEGREENAREADISTANCE_LOG       0.0
# LX_PST_P1B3C_65_ELENGINEGREENAREATORQUETIME_LO      0.0
# LX_PST_P1B3C_66_ELENGINEGREENAREATORQUEFUEL_LO      0.0
# LX_PST_P1B3C_67_ELENGINEGREENAREATORQUEDISTANC      0.0
# LX_PST_P1B3R_59_ELFUELCONSUMPTIONPTO_LOG            0.0
# LX_PST_P1B3R_60_ELFUELCONSUMPTIONVEHICLERUNNIN      0.0
# LX_PST_P1B3R_61_ELFUELCONSUMPTIONVEHICLESTOPPE      0.0
# LX_PST_P1C2O_362_VDLCOMPRDISJUNCTIONTIME_LOG        0.0
# LX_PST_P1C2O_363_VDLCOMPRCONJUNCTIONNOTTRACTION     0.0
# LX_PST_P1C2O_364_VDLCOMPRCONJUNCTIONTRACTIONTIM     0.0
# LX_PST_P1C3B_124_VDLOVERSPEEDCOUNTER_LOG            0.0
# LX_PSC_P1AS3_MAIN_LOG_COASTING_DISTANCE             0.0
# LX_PSC_P1ARN_CLUTCH_NUMBER_SLIP_ABUSE               0.0
# X_PST_P1ENC_21_PMLININGWEARMONITOR_LOG              0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_11       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_3                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_30                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_31                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_4                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_5                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_6                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_7                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_8                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_9                        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_1        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_10       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_12       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_28                       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_13       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_14       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_15       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_16       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_17       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_2        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_3        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_4        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_5        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_6        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_7        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_29                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_27                       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_9        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_14                       0.0
# MONTH                                               0.0
# YEAR                                                0.0
# Malfunction_Label                                   0.0
# RUL                                                 0.0
# DELIVERY_DATE.1                                     0.0
# T_CHASSIS                                           0.0
# INT_BWSD                                            0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_10                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_11                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_12                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_13                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_15                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_26                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_16                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_17                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_18                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_19                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_2                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_20                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_21                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_22                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_23                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_24                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_25                       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_8        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_1        0.0
# LX_PSC_P1ARL_BRAKE_MODE_DISTANCE                    0.0
# LX_PSC_P1AQP_POWER_MODE_DISTANCE                    0.0
# LX_PSC_P1AQE_GEARBOX_MOVEMENT_GEAR1R_GEARR          0.0
# LX_PSC_P1AQF_GEARBOX_MOVEMENT_GEAR1R_NEUTRA         0.0
# LX_PSC_P1AQG_GEARBOX_MOVEMENT_GEAR23_GEAR2          0.0
# LX_PSC_P1AQH_GEARBOX_MOVEMENT_GEAR23_GEAR3          0.0
# LX_PSC_P1AQI_GEARBOX_MOVEMENT_GEAR23_NEUTRA         0.0
# LX_PSC_P1AQJ_GEARBOX_MOVEMENT_SPLIT_DIRECT          0.0
# LX_PSC_P1AQK_GEARBOX_MOVEMENT_SPLIT_INDIREC         0.0
# LX_PSC_P1AQL_GEARBOX_MOVEMENT_SPLIT_NEUTRAL         0.0
# LX_PSC_P1AQM_GEARBOX_MOVEMENT_RANGE_LOW             0.0
# LX_PSC_P1AQN_GEARBOX_MOVEMENT_RANGE_HIGH            0.0
# LX_PSC_P1AQO_POWER_MODE_TIME                        0.0
# LX_PSC_P1AQQ_POWER_MODE_FUEL                        0.0
# LX_PSC_P1AQ7_ENTERED_BACKUP_MODE                    0.0
# LX_PSC_P1AQR_BRAKE_MODE_TIME                        0.0
# LX_PSC_P1AQT_ECOROLL_ENABLED_TIME                   0.0
# LX_PSC_P1AQU_ECOROLL_ACTIVE_TIME                    0.0
# LX_PSC_P1AQV_ECOROLL_ENABLED_DISTANCE               0.0
# LX_PSC_P1AQW_ECOROLL_ACTIVE_DISTANCE                0.0
# LX_PSC_P1AQX_ENTERED_ECONOMY_MODE                   0.0
# LX_PSC_P1AQY_ENTERED_POWER_MODE                     0.0
# LX_PSC_P1AQZ_ENTERED_BRAKE_MODE                     0.0
# LX_PSC_P1ARB_ECONOMY_MODE_TIME                      0.0
# LX_PSC_P1ARC_ECONOMY_MODE_DISTANCE                  0.0
# LX_PSC_P1ARD_ECONOMY_MODE_FUEL                      0.0
# LX_PSC_P1AQD_GEARBOX_MOVEMENT_GEAR1R_GEAR1          0.0
# LX_PSC_P1AQ5_PRESS_DOWN_MANUAL                      0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_10       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_6        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_11       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_12       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_13       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_14       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_15       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_16       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_17       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_2        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_3        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_4        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_5        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_7        0.0
# LX_PSC_P1AQ4_PRESS_UP_MANUAL                        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_8        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_9        0.0
# LX_PSC_P1AP5_GEAR_LEVER_AUTOMATIC_DISTANCE          0.0
# LX_PSC_P1AP6_GEAR_LEVER_MANUAL_DISTANCE             0.0
# LX_PSC_P1APL_CLUTCH_TIME_DISENGAGED                 0.0
# LX_PSC_P1APP_GEAR_LEVER_AUTOMATIC_TIME              0.0
# LX_PSC_P1APQ_GEAR_LEVER_MANUAL_TIME                 0.0
# LX_PSC_P1APU_CLUTCH_NUMBER_DISENGAGES               0.0
# LX_PSC_P1AQ1_LEVER_MOVED_FROM_AUTO_TO_MAN           0.0
# LX_PSC_P1AQ2_PRESS_UP_AUTO                          0.0
# LX_PSC_P1AQ3_PRESS_DOWN_AUTO                        0.0
# X_PST_P1H6B_135_HCCATCOMP                           0.0
# X_PST_P1ENC_19_PMLININGWEARAXLENUMBER_LOG           0.0
# VFE_0009_LTVF_TYPE                                  0.0
# VFE_0006_VEHICLE_OPERATION_DIGIT2                   0.0
# SLX_PFE_0001_FUEL_OVER_MILEAGE                      0.0
# SLX_PFE_0002_PTO_OVER_ENGINETIME                    0.0
# SLX_PFE_0003_IDLE_OVER_ENGINETIME                   0.0
# SLX_PFE_0004_UREA_OVER_FUEL                         0.0
# SLX_PFE_0005_CLUTCH_OVER_MILEAGE                    0.0
# SLX_PFE_0006_PARK_OVER_MILAGE                       0.0
# SLX_PFE_0007_PCT_DISTANCE_IN_AUTOMATIC_MODE         0.0
# SLX_PFE_0008_NBR_OF_GEARSHIFTS                      0.0
# SLX_PFE_0009_PCT_TOP_GEAR                           0.0
# LX_PSC_P1BBY_TOTAL_FUEL_CONSUMPTION                 0.0
# VFE_0005_VEHICLE_OPERATION_DIGIT1                   0.0
# VFE_0008_HAS_PTO                                    0.0
# SX_PSC_P1AQ6_ENTERED_LIMPHOME_MODE                  0.0
# VAR_DAX_AXLE_ARRANGEMENT                            0.0
# COUNTRY_OF_OPERATION                                0.0
# VAR_7MA_FRONT_AXLE_TYPE                             0.0
# VAR_DPX_ENGINE_TYPE                                 0.0
# VAR_T1X_PTO_ENGINE_MOUNTED_REAR                     0.0
# VAR_4DX_FRONT_BUMPER                                0.0
# VAR_F1X_REAR_AXLE_LOAD                              0.0
# VAR_FTX_GROUND_CLEARANCE_FA                         0.0
# VAR_CKX_VEHICLE_PROFILE                             0.0
# VAR_KTX_ENGINE_EMISSION_CONTROL                     0.0
# VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP                 0.0
# SX_PSC_P1AQ0_ENTERED_KICKDOWN_MODE                  0.0
# SX_PSC_P1AQ8_ENTERED_NO_SPEED_MODE                  0.0
# VAR_YLX_REAR_SUSPENSION_SYSTEM                      0.0
# SLX_PSC_P1EVS_CLUTCH_PLATE_WEAR                     0.0
# SLX_PSC_P1ATE_MAIN_LOG_IDLE_TIME                    0.0
# SLX_PSC_P1ATH_MAIN_LOG_PTO_TIME                     0.0
# SLX_PSC_P1ATJ_MAIN_LOG_VTC_ENGINE_SPEED_TIME        0.0
# SLX_PSC_P1ATN_MAIN_LOG_VTC_ENGINE_SPEED_FUEL        0.0
# SLX_PSC_P1BB0_TOTAL_ENGINE_TIME                     0.0
# SLX_PSC_P1BBX_TIME_IN_TOP_GEAR                      0.0
# SLX_PSC_P1BBY_TOTAL_FUEL_CONSUMPTION                0.0
# SLX_PSC_P1E0O_TOTAL_NUMBER_OF_PARK_BRAKE_MAN        0.0
# SLX_PSC_P1E0P_TOTAL_NUMBER_OF_AUTOMATIC_PARK        0.0
# SLX_PSC_P1E0Q_TOTAL_NUMBER_OF_AUTOMATIC_PARK        0.0
# SLX_PSC_P1E8Y_TOTAL_NUMBER_OF_PARK_BRAKE_APP        0.0
# SLX_PSC_P1FXC_UREA_SYSTEM_ERROR_COUNT_LOG           0.0
# SX_PSC_P1AQ9_ENTERED_FAULTY_GEARBOX_MODE            0.0
# SLX_PSC_P1FY7_TOP_GEAR_1_MODE_TOTAL_DISTANCE        0.0
# SLX_PSC_P1IPV_INJECTED_UREA_TOTAL_MASS              0.0
# SLX_PSC_P1IPX_TOTAL_INJECTED_UREA__L                0.0
# SLX_PSC_P1ITX_FUEL_CONSUMPTION_DURING_MOVING        0.0
# SLX_PSC_P1JR3_AUTOMATIC_SULPHUR_FUEL_REGENER        0.0
# SLX_PST_P1E1E_813_OPERATION_TIME                    0.0
# SLX_TOTAL_VEHICLE_DISTANCE_RULE_BASED               0.0
# SX_PSC_P1ITY_NUMBER_OF_PARKED_REGENERATIONS         0.0
# SX_PSC_P1ITW_FUEL_CONSUMPTION_DURING_PARKED         0.0
# SX_PSC_P1ARA_ENTERED_DYNAMOMETER_MODE               0.0
# SX_PSC_P1AQS_KICKDOWN_MODE_TIME                     0.0
# VAR_QCX_TOPOGRAPHY                                  0.0
# VAR_DKX_GROSS_COMBINATION_WEIGHT                    0.0
# SLX_PSC_P1ASV_MAIN_LOG_DRIVE_TIME                   0.0
# VAR_DHX_ROAD_CONDITION                              0.0
# VAR_FZX_FRONT_AXLE_ARRANGEMENT                      0.0
# VAR_V6X_RETARDER                                    0.0
# VAR_K4C_VEHICLE_UPTIME_SETTINGS                     0.0
# VAR_0RA_REGENERATION_CONTROLS_DPF                   0.0
# VAR_YKX_FRONT_SUSPENSION_SYSTEM                     0.0
# VAR_T3X_PTO_ENGINE_REAR_MOUNTED                     0.0
# VAR_PJX_ALTERNATOR_CAPACITY                         0.0
# VAR_41X_PARKING_HEATER                              0.0
# VAR_D7C_WHOLE_VEHICLE_TYPE_APPROVAL                 0.0
# VAR_5JB_TELEMATICS_COMMUNICAT_GATEWAYS              0.0
# VAR_RWX_TRANSMISSION                                0.0
# VAR_2EX_CAB_TILT_PUMP                               0.0
# VAR_LKX_DRIVER_STATE_SENSING_SYSTEM                 0.0
# VAR_D9C_EMISSION_LEVEL                              0.0
# VAR_DDX_CHASSIS_TYPE                                0.0
# VAR_O8A_ENGINE_PTO_TORQUE_CAPACITY                  0.0
# VAR_33A_CAB_HEIGHT                                  0.0
# VAR_J2A_ACTIVE_STEERING                             0.0
# VAR_N9C_ADR_CLASSIFICATION                          0.0
# VFE_0001_HORSE_POWER                                0.0
# VFE_0002_GROSS_COMBINATION_WEIGHT_BIN               0.0
# VFE_0003_ENGINE_GENERATION                          0.0
# VFE_0004_REAR_AXLE_LOAD_BIN                         0.0
# VFE_0005_REAR_AXLE_RATIO_BIN                        0.0
# VAR_QWX_TURBO                                       0.0
# VAR_7NA_FRONT_SUSPENSION_INSTALLATION               0.0
# VAR_2RB_BATTERY_MAINTENANCE                         0.0
# VAR_RUX_GEAR_SHIFTING_SYSTEM                        0.0
# VAR_FAX_STEERING_WHEEL_POS                          0.0
# VAR_2CX_CAB_VERSION                                 0.0
# VAR_2DX_REAR_CAB_SUSPENSION                         0.0
# VAR_GSX_CHASSIS_HEIGHT                              0.0
# VAR_FFX_PUSHER_AXLE_FEATURES                        0.0
# VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE                   0.0
# VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR                   0.0
# VAR_5NX_ENGINE_BLOCK_HEATER                         0.0
# VAR_TAX_REAR_AXLE_RATIO                             0.0
# VAR_A3A_IDLE_SHUTDOWN                               0.0
# VAR_2LX_FRONT_CAB_SUSPENSION                        0.0
# VAR_U3X_BRAKE_FRONT                                 0.0
# VAR_7PX_HYDRAULIC_PUMP_GEARBOX_MOUNTED              0.0
# VAR_T4X_PTO_TRANSM_MOUNTED                          0.0
# VAR_UBX_HYDRAULIC_PUMP_ENG_MTD                      0.0
# VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS               0.0
# VAR_REX_CRANK_CASE_VENTILATION                      0.0
# VAR_78X_TRANSPORT_CYCLE                             0.0
# VAR_T2X_TRANSMISSIONRETARDER_COOLER                 0.0
# VAR_U4X_BRAKE_DRIVE_REAR                            0.0
# VAR_FVX_FRONT_AXLE_LOAD                             0.0
# VAR_VWX_COMPRESSOR_CAPACITY                         0.0
# VAR_H1B_TURBO_APPLICATION                           0.0
# VAR_FDX_REAR_AXLE_ARRANGEMENT                       0.0
# SLX_PSC_P1ASW_MAIN_LOG_IDLE_FUEL                    0.0
# SLX_PSC_P1ASR_MAIN_LOG_CRUISE_TIME                  0.0
# X_PST_P1ENC_18_PMLININGWEARPREDICTIVEMILEAGE_       0.0
# X_PSC_P1JA8_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBI_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBH_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBG_UREA_ADAPTION_NWM_PARAMERTER_9          0.0
# X_PSC_P1JBF_UREA_ADAPTION_NWM_PARAMERTER_8          0.0
# X_PSC_P1JBE_UREA_ADAPTION_NWM_PARAMERTER_7          0.0
# X_PSC_P1JBD_UREA_ADAPTION_NWM_PARAMERTER_6          0.0
# X_PSC_P1JBC_UREA_ADAPTION_NWM_PARAMERTER_5          0.0
# X_PSC_P1JBB_UREA_ADAPTION_NWM_PARAMERTER_4          0.0
# X_PSC_P1JBA_UREA_ADAPTION_NWM_PARAMERTER_3          0.0
# X_PSC_P1JAZ_RATED_ENGINE_POWER                      0.0
# X_PSC_P1JA9_UREA_ADAPTION_NWM_PARAMERTER_2          0.0
# X_PSC_P1ITY_NUMBER_OF_PARKED_REGENERATIONS          0.0
# X_PSC_P1JBK_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1ITW_FUEL_CONSUMPTION_DURING_PARKED          0.0
# X_PSC_P1IT7_NUMBER_OF_TIMES_THE_ESTIMATED_          0.0
# X_PSC_P1IT2_AFTERTREATMENT_REGENERATION_IN          0.0
# X_PSC_P1IPW_TOTAL_USED_UREA__G                      0.0
# X_PSC_P1IPO_MINIMUM_UREA_QUALITY_MASS__AT_          0.0
# X_PSC_P1IPN_MAXIMUM_UREA_QUALITY_MASS__AT_          0.0
# X_PSC_P1IPM_UREA_QUALITY_MASS_SAVED_AT_POW          0.0
# X_PSC_P1IOY_SOOT_MASS_REPORTED_BY_KALMAN_F          0.0
# X_PSC_P1I9E_NUMBER_OF_TIMES_THE_WATER_IN_F          0.0
# X_PSC_P1HUB_SOFT_CRUISE_ENABLE                      0.0
# X_PSC_P1HTM_SOOT_LEVEL                              0.0
# X_PSC_P1JBJ_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBL_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1F0I_ENGINE_INTAKE_AIR_MASS_FLOW_RA          0.0
# X_PSC_P1K8T_NUMBER_OF_SUCCESSIVE_INTERRUPT          0.0
# X_PST_P1EM9_16_PMAIRDRYERCARTRIDGEMONITOR_LOG       0.0
# X_PST_P1EM9_15_PMAIRDRYERCARTRIDGEPERCENTAGEW       0.0
# X_PST_P1EM9_14_PMAIRDRYERCARTRIDGEPREDICTIVEM       0.0
# X_PST_P1E1E_811_COMP_DUTY_CYCLE                     0.0
# X_PST_P1E1D_1076_MILEAGE_CARTRIDGE_N1               0.0
# X_PST_P1E1D_1075_TAV_CARTRIDGE_N1                   0.0
# X_PST_P1C3B_128_VDLRSL2NDTHRESHOLDACTIVEDISTAN      0.0
# X_PST_P1C2O_365_VDLCOMPRTOTALTIME_LOG               0.0
# X_PST_P1C2J_527_TLDRIVINGMONSYSTEMRECOMMENDEDG      0.0
# X_PSC_P1LJQ_ADBLUE_ADAPTION_FACTOR_INITIAL          0.0
# X_PSC_P1KOA_SPECIFIC_NOX_EMISSIONS_AT_EXHA          0.0
# X_PSC_P1K8S_NUMBER_OF_SUCCESSIVE_FAILED_RE          0.0
# X_PSC_P1JBM_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JRY_AUTOMATIC_SOOT_KF_REGENERATION          0.0
# X_PSC_P1JRX_AUTOMATIC_SOOT_PM_REGENERATION          0.0
# X_PSC_P1JRW_AUTOMATIC_SOOT_TIME_REGENERATI          0.0
# X_PSC_P1JRU_AUTOMATIC_SOOT_DISTANCE_REGENE          0.0
# X_PSC_P1JRT_PARKED_SULPHUR_REGENERATION_TR          0.0
# X_PSC_P1JRQ_PARKED_SOOT_REGENERATION_TRIGG          0.0
# X_PSC_P1JR5_AUTOMATIC_SULPHUR_DPF_REGENERA          0.0
# X_PSC_P1JR2_AUTOMATIC_HC_DPF_REGENERATION_          0.0
# X_PSC_P1JR0_AUTOMATIC_CRYSTALS_REGENERATIO          0.0
# X_PSC_P1JBT_SCR_OPERATOR_INDUCEMENT_REASON          0.0
# X_PSC_P1JBN_UREA_ADAPTION_FACTOR_NWM_PARAM          0.0
# X_PSC_P1FXO_YAXIS_OF_EXHAUST_TEMPERATURE_1          0.0
# X_PSC_P1EZH_TOTAL_NUMBER_OF_TRAILER_TEST_A          0.0
# SLX_PSC_P1ASQ_MAIN_LOG_CRUISE_FUEL                  0.0
# SLX_PSC_P1AQP_POWER_MODE_DISTANCE                   0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_18        0.0
# X_PMU_P1FH1_SLOPE_X_INDEX_32                        0.0
# X_PMU_P1FH1_SLOPE_X_INDEX_1                         0.0
# AGE_MONTHS                                          0.0
# AGE_YEARS                                           0.0
# SLX_PSC_P1APL_CLUTCH_TIME_DISENGAGED                0.0
# SLX_PSC_P1APU_CLUTCH_NUMBER_DISENGAGES              0.0
# SLX_PSC_P1AQ1_LEVER_MOVED_FROM_AUTO_TO_MAN          0.0
# SLX_PSC_P1AQ7_ENTERED_BACKUP_MODE                   0.0
# SLX_PSC_P1AQE_GEARBOX_MOVEMENT_GEAR1R_GEARR         0.0
# SLX_PSC_P1AQG_GEARBOX_MOVEMENT_GEAR23_GEAR2         0.0
# SLX_PSC_P1AQQ_POWER_MODE_FUEL                       0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_20        0.0
# SLX_PSC_P1AQR_BRAKE_MODE_TIME                       0.0
# SLX_PSC_P1AQU_ECOROLL_ACTIVE_TIME                   0.0
# SLX_PSC_P1AQX_ENTERED_ECONOMY_MODE                  0.0
# SLX_PSC_P1AQY_ENTERED_POWER_MODE                    0.0
# SLX_PSC_P1AQZ_ENTERED_BRAKE_MODE                    0.0
# SLX_PSC_P1ARB_ECONOMY_MODE_TIME                     0.0
# SLX_PSC_P1ARL_BRAKE_MODE_DISTANCE                   0.0
# SLX_PSC_P1ARN_CLUTCH_NUMBER_SLIP_ABUSE              0.0
# SLX_PSC_P1AS4_MAIN_LOG_ECON_DISTANCE                0.0
# SLX_PSC_P1AS6_MAIN_LOG_PTO_DISTANCE                 0.0
# SLX_PSC_P1AS9_MAIN_LOG_BRAKE_TIME                   0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_19        0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_18        0.0
# X_PSC_P1EII_WFACTOR                                 0.0
# X_PSC_P1ATP_OIL__DEGRADATION_DISTANCE_STAR          0.0
# X_PSC_P1E0I_AIR_PRODUCTION_MODULATOR_CARTR          0.0
# X_PSC_P1E09_VEHICLE_AIR_LEAKAGE_ESTIMATED           0.0
# X_PSC_P1C04_VEHICLE_WEIGHT_WITH_TRAILER_ME          0.0
# X_PSC_P1BVS_IDLE_SHUTDOWN_IDLE_TIMER_VALUE          0.0
# X_PSC_P1B99_AIR_PRODUCTION_MODULATOR_TOTAL          0.0
# X_PSC_P1ATX_OIL_STATUS                              0.0
# X_PSC_P1ATW_OIL_QUALITY                             0.0
# X_PSC_P1ATV_OIL_LIFE_AT_PAST_DUE                    0.0
# X_PSC_P1ATS_OIL_DEGRADATION_LAST_OLC_HOURS          0.0
# X_PSC_P1ATR_OIL_DEGRADATION_LAST_OLC_DISTA          0.0
# X_PSC_P1ATQ_OIL__DEGRADATION_HOURS_START            0.0
# X_PSC_P1ARM_KICKDOWN_MODE_DISTANCE                  0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_19        0.0
# X_PSC_P1ARA_ENTERED_DYNAMOMETER_MODE                0.0
# X_PSC_P1AQS_KICKDOWN_MODE_TIME                      0.0
# X_PSC_P1AQ9_ENTERED_FAULTY_GEARBOX_MODE             0.0
# X_PSC_P1AQ8_ENTERED_NO_SPEED_MODE                   0.0
# X_PSC_P1AQ6_ENTERED_LIMPHOME_MODE                   0.0
# X_PSC_P1AQ0_ENTERED_KICKDOWN_MODE                   0.0
# X_PSC_P1AOD_DIFF_RSL_MAX_VSPD_NEXT_HIGHEST          0.0
# X_PSC_P1AL0_DIFFERENTIATED_RSL_ENABLE               0.0
# X_PSC_P1AFR_OUTDOOR_TEMPERATURE                     0.0
# X_PSC_MI_ENABLE_IMMOBILISER                         0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_20        0.0
# DAY                                                 0.0
# dtype: float64
# missing values rate after:  VFE_0007_CAB_HEIGHT                                 0.0
# LX_PSC_P1E0Q_TOTAL_NUMBER_OF_AUTOMATIC_PARK         0.0
# LX_PSC_P1ATN_MAIN_LOG_VTC_ENGINE_SPEED_FUEL         0.0
# LX_PSC_P1ATO_MAIN_LOG_TOTAL_ENERGY                  0.0
# LX_PSC_P1BB0_TOTAL_ENGINE_TIME                      0.0
# LX_PSC_P1BBV_DISTANCE_IN_TOP_GEAR                   0.0
# LX_PSC_P1BBW_FUEL_IN_TOP_GEAR                       0.0
# LX_PSC_P1BBX_TIME_IN_TOP_GEAR                       0.0
# LX_PSC_P1BBZ_TOTAL_ENGINE_REVOLUTIONS               0.0
# LX_PSC_P1C5K_BRAKING_WITH_BIG_DECELERATION          0.0
# LX_PSC_P1E0N_TOTAL_NUMBER_OF_PARK_BRAKE_MAN         0.0
# LX_PSC_P1E0O_TOTAL_NUMBER_OF_PARK_BRAKE_MAN         0.0
# LX_PSC_P1E0P_TOTAL_NUMBER_OF_AUTOMATIC_PARK         0.0
# LX_PSC_P1E8Y_TOTAL_NUMBER_OF_PARK_BRAKE_APP         0.0
# LX_PSC_P1ATL_MAIN_LOG_PEDAL_FUEL                    0.0
# LX_PSC_P1EVS_CLUTCH_PLATE_WEAR                      0.0
# LX_PSC_P1FUN_NUMBER_OF_ENGINE_STARTS_DURING         0.0
# LX_PSC_P1FUO_NUMBER_OF_STARTER_ACTIVATION_D         0.0
# LX_PSC_P1FXC_UREA_SYSTEM_ERROR_COUNT_LOG            0.0
# LX_PSC_P1FXD_TIME_WITH_UREA_SYSTEM_ERROR_LO         0.0
# LX_PSC_P1FY7_TOP_GEAR_1_MODE_TOTAL_DISTANCE         0.0
# LX_PSC_P1FY8_TOP_GEAR_1_MODE_TOTAL_FUEL             0.0
# LX_PSC_P1FY9_TOP_GEAR_1_MODE_TOTAL_TIME             0.0
# LX_PSC_P1FYO_TOTAL_TIME_IN_IDLE_MODE_PTO            0.0
# LX_PSC_P1I80_TOP_VALUE_OF_ENGINE_SPEED_IN_O         0.0
# LX_PSC_P1IPV_INJECTED_UREA_TOTAL_MASS               0.0
# LX_PSC_P1ATM_MAIN_LOG_ROAD_SPEED_LIMIT_FUEL         0.0
# LX_PSC_P1ATK_MAIN_LOG_ECONOMICAL_FUEL               0.0
# LX_PSC_P1IT0_AFTERTREATMENT_REGENERATION_IN         0.0
# LX_PSC_P1ASU_MAIN_LOG_DRIVE_FUEL                    0.0
# LX_PSC_P1AS4_MAIN_LOG_ECON_DISTANCE                 0.0
# LX_PSC_P1AS5_MAIN_LOG_PEDAL_DISTANCE                0.0
# LX_PSC_P1AS6_MAIN_LOG_PTO_DISTANCE                  0.0
# LX_PSC_P1AS7_MAIN_LOG_ROAD_SPEED_LIMIT_DIST         0.0
# LX_PSC_P1AS9_MAIN_LOG_BRAKE_TIME                    0.0
# LX_PSC_P1ASH_COOLANT_PUMP_NUMBER_OF_ACTIVAT         0.0
# LX_PSC_P1ASI_COOLANT_PUMP_ACTIVATION_TIME           0.0
# LX_PSC_P1ASP_MAIN_LOG_CRUISE_DISTANCE               0.0
# LX_PSC_P1ASQ_MAIN_LOG_CRUISE_FUEL                   0.0
# LX_PSC_P1ASR_MAIN_LOG_CRUISE_TIME                   0.0
# LX_PSC_P1AST_MAIN_LOG_DRIVE_DISTANCE                0.0
# LX_PSC_P1ASV_MAIN_LOG_DRIVE_TIME                    0.0
# LX_PSC_P1ATJ_MAIN_LOG_VTC_ENGINE_SPEED_TIME         0.0
# LX_PSC_P1ASW_MAIN_LOG_IDLE_FUEL                     0.0
# LX_PSC_P1ASX_MAIN_LOG_PTO_FUEL                      0.0
# LX_PSC_P1ATA_MAIN_LOG_COASTING_TIME                 0.0
# LX_PSC_P1ATB_MAIN_LOG_CUSTOMER_ENGINE_SPEED         0.0
# LX_PSC_P1ATC_MAIN_LOG_CUSTOMER_VEHICLE_SPEE         0.0
# LX_PSC_P1ATD_MAIN_LOG_ECONOMICAL_TIME               0.0
# LX_PSC_P1ATE_MAIN_LOG_IDLE_TIME                     0.0
# LX_PSC_P1ATF_MAIN_LOG_KEY_ON_TIME                   0.0
# LX_PSC_P1ATG_MAIN_LOG_PEDAL_TIME                    0.0
# LX_PSC_P1ATH_MAIN_LOG_PTO_TIME                      0.0
# LX_PSC_P1ATI_MAIN_LOG_ROAD_SPEED_LIMIT_TIME         0.0
# LX_PSC_P1IPX_TOTAL_INJECTED_UREA__L                 0.0
# LX_PSC_P1IT1_AFTERTREATMENT_REGENERATION_IN         0.0
# LX_PSC_P1AS2_MAIN_LOG_BRAKE_DISTANCE                0.0
# LX_PST_P1H6B_137_NCATCOMP                           0.0
# LX_PST_P1E0L_1072_MV3                               0.0
# LX_PST_P1E0L_1073_MV4                               0.0
# LX_PST_P1E0L_1074_MV5                               0.0
# LX_PST_P1E1E_812_TAV_COMP                           0.0
# LX_PST_P1E1E_813_OPERATION_TIME                     0.0
# LX_PST_P1EM9_11_PMAIRDRYERCARTRIDGERESETCALEND      0.0
# LX_PST_P1EM9_12_PMAIRDRYERCARTRIDGERESETVEHICL      0.0
# LX_PST_P1EM9_13_PMAIRDRYERCARTRIDGERESETENGINE      0.0
# LX_PST_P1H6B_133_OBDCOND                            0.0
# LX_PST_P1H6B_134_IGNCNTR                            0.0
# LX_PST_P1H6B_136_HCCATCOND                          0.0
# LX_PST_P1H6B_138_NCATCOND                           0.0
# LX_PST_P1C3B_127_VDLOVERSPEEDDISTANCE_LOG           0.0
# LX_PST_P1H6B_141_PMCOMP                             0.0
# LX_PST_P1H6B_142_PMCOND                             0.0
# LX_PST_P1H6B_143_EGSCOMP                            0.0
# LX_PST_P1H6B_144_EGSCOND                            0.0
# LX_PST_P1H6B_145_EGRCOMP                            0.0
# LX_PST_P1H6B_146_EGRCOND                            0.0
# LX_PST_P1H6B_147_BPCOMP                             0.0
# LX_PST_P1H6B_148_BPCOND                             0.0
# LX_PST_P1H6B_149_FUELCOMP                           0.0
# LX_PST_P1H6B_150_FUELCOND                           0.0
# LX_TOTAL_VEHICLE_DISTANCE_RULE_BASED                0.0
# LX_PST_P1C3B_129_VDLOVERSPEEDMAX_LOG                0.0
# LX_PST_P1C3B_126_VDLOVERSPEEDFUEL_LOG               0.0
# LX_PSC_P1ITX_FUEL_CONSUMPTION_DURING_MOVING         0.0
# LX_PST_P1B3C_62_ELENGINEGREENAREATIME_LOG           0.0
# LX_PSC_P1IV0_AIR_PRODUCTION_MODULATOR_HEATE         0.0
# LX_PSC_P1J63_ELECTRONIC_STABILITY_PROGRAMES         0.0
# LX_PSC_P1J65_BRAKE_ASSIST_DATA                      0.0
# LX_PSC_P1JR3_AUTOMATIC_SULPHUR_FUEL_REGENER         0.0
# LX_PSC_P1MNF_COMPRESSOR_LOAD_PHASE_COUNTER          0.0
# LX_PST_P1B2W_87_ELLOWIDLESPEEDVEHICLESTOPPEDTI      0.0
# LX_PST_P1B2W_88_ELLOWIDLESPEEDVEHICLESTOPPEDFU      0.0
# LX_PST_P1B3A_2156_BCLVEHICLEMODEACCESSORYTIME_LO    0.0
# LX_PST_P1B3A_329_BCLVEHICLEMODELIVINGTIME_LOG       0.0
# LX_PST_P1B3A_331_BCLVEHICLEMODEPRERUNNINGTIME_L     0.0
# LX_PST_P1B3A_332_BCLVEHICLEMODECRANKINGTIME_LOG     0.0
# LX_PST_P1B3C_63_ELENGINEGREENAREAFUEL_LOG           0.0
# LX_PST_P1C3B_125_VDLOVERSPEEDTIME_LOG               0.0
# LX_PST_P1B3C_64_ELENGINEGREENAREADISTANCE_LOG       0.0
# LX_PST_P1B3C_65_ELENGINEGREENAREATORQUETIME_LO      0.0
# LX_PST_P1B3C_66_ELENGINEGREENAREATORQUEFUEL_LO      0.0
# LX_PST_P1B3C_67_ELENGINEGREENAREATORQUEDISTANC      0.0
# LX_PST_P1B3R_59_ELFUELCONSUMPTIONPTO_LOG            0.0
# LX_PST_P1B3R_60_ELFUELCONSUMPTIONVEHICLERUNNIN      0.0
# LX_PST_P1B3R_61_ELFUELCONSUMPTIONVEHICLESTOPPE      0.0
# LX_PST_P1C2O_362_VDLCOMPRDISJUNCTIONTIME_LOG        0.0
# LX_PST_P1C2O_363_VDLCOMPRCONJUNCTIONNOTTRACTION     0.0
# LX_PST_P1C2O_364_VDLCOMPRCONJUNCTIONTRACTIONTIM     0.0
# LX_PST_P1C3B_124_VDLOVERSPEEDCOUNTER_LOG            0.0
# LX_PSC_P1AS3_MAIN_LOG_COASTING_DISTANCE             0.0
# LX_PSC_P1ARN_CLUTCH_NUMBER_SLIP_ABUSE               0.0
# X_PST_P1ENC_21_PMLININGWEARMONITOR_LOG              0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_11       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_3                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_30                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_31                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_4                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_5                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_6                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_7                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_8                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_9                        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_1        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_10       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_12       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_28                       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_13       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_14       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_15       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_16       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_17       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_2        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_3        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_4        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_5        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_6        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_7        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_29                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_27                       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_9        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_14                       0.0
# MONTH                                               0.0
# YEAR                                                0.0
# Malfunction_Label                                   0.0
# RUL                                                 0.0
# DELIVERY_DATE.1                                     0.0
# T_CHASSIS                                           0.0
# INT_BWSD                                            0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_10                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_11                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_12                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_13                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_15                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_26                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_16                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_17                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_18                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_19                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_2                        0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_20                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_21                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_22                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_23                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_24                       0.0
# LX_PMU_P1FH1_SLOPE_X_INDEX_25                       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_8        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_1        0.0
# LX_PSC_P1ARL_BRAKE_MODE_DISTANCE                    0.0
# LX_PSC_P1AQP_POWER_MODE_DISTANCE                    0.0
# LX_PSC_P1AQE_GEARBOX_MOVEMENT_GEAR1R_GEARR          0.0
# LX_PSC_P1AQF_GEARBOX_MOVEMENT_GEAR1R_NEUTRA         0.0
# LX_PSC_P1AQG_GEARBOX_MOVEMENT_GEAR23_GEAR2          0.0
# LX_PSC_P1AQH_GEARBOX_MOVEMENT_GEAR23_GEAR3          0.0
# LX_PSC_P1AQI_GEARBOX_MOVEMENT_GEAR23_NEUTRA         0.0
# LX_PSC_P1AQJ_GEARBOX_MOVEMENT_SPLIT_DIRECT          0.0
# LX_PSC_P1AQK_GEARBOX_MOVEMENT_SPLIT_INDIREC         0.0
# LX_PSC_P1AQL_GEARBOX_MOVEMENT_SPLIT_NEUTRAL         0.0
# LX_PSC_P1AQM_GEARBOX_MOVEMENT_RANGE_LOW             0.0
# LX_PSC_P1AQN_GEARBOX_MOVEMENT_RANGE_HIGH            0.0
# LX_PSC_P1AQO_POWER_MODE_TIME                        0.0
# LX_PSC_P1AQQ_POWER_MODE_FUEL                        0.0
# LX_PSC_P1AQ7_ENTERED_BACKUP_MODE                    0.0
# LX_PSC_P1AQR_BRAKE_MODE_TIME                        0.0
# LX_PSC_P1AQT_ECOROLL_ENABLED_TIME                   0.0
# LX_PSC_P1AQU_ECOROLL_ACTIVE_TIME                    0.0
# LX_PSC_P1AQV_ECOROLL_ENABLED_DISTANCE               0.0
# LX_PSC_P1AQW_ECOROLL_ACTIVE_DISTANCE                0.0
# LX_PSC_P1AQX_ENTERED_ECONOMY_MODE                   0.0
# LX_PSC_P1AQY_ENTERED_POWER_MODE                     0.0
# LX_PSC_P1AQZ_ENTERED_BRAKE_MODE                     0.0
# LX_PSC_P1ARB_ECONOMY_MODE_TIME                      0.0
# LX_PSC_P1ARC_ECONOMY_MODE_DISTANCE                  0.0
# LX_PSC_P1ARD_ECONOMY_MODE_FUEL                      0.0
# LX_PSC_P1AQD_GEARBOX_MOVEMENT_GEAR1R_GEAR1          0.0
# LX_PSC_P1AQ5_PRESS_DOWN_MANUAL                      0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_10       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_6        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_11       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_12       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_13       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_14       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_15       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_16       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_17       0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_2        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_3        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_4        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_5        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_7        0.0
# LX_PSC_P1AQ4_PRESS_UP_MANUAL                        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_8        0.0
# LX_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_9        0.0
# LX_PSC_P1AP5_GEAR_LEVER_AUTOMATIC_DISTANCE          0.0
# LX_PSC_P1AP6_GEAR_LEVER_MANUAL_DISTANCE             0.0
# LX_PSC_P1APL_CLUTCH_TIME_DISENGAGED                 0.0
# LX_PSC_P1APP_GEAR_LEVER_AUTOMATIC_TIME              0.0
# LX_PSC_P1APQ_GEAR_LEVER_MANUAL_TIME                 0.0
# LX_PSC_P1APU_CLUTCH_NUMBER_DISENGAGES               0.0
# LX_PSC_P1AQ1_LEVER_MOVED_FROM_AUTO_TO_MAN           0.0
# LX_PSC_P1AQ2_PRESS_UP_AUTO                          0.0
# LX_PSC_P1AQ3_PRESS_DOWN_AUTO                        0.0
# X_PST_P1H6B_135_HCCATCOMP                           0.0
# X_PST_P1ENC_19_PMLININGWEARAXLENUMBER_LOG           0.0
# VFE_0009_LTVF_TYPE                                  0.0
# VFE_0006_VEHICLE_OPERATION_DIGIT2                   0.0
# SLX_PFE_0001_FUEL_OVER_MILEAGE                      0.0
# SLX_PFE_0002_PTO_OVER_ENGINETIME                    0.0
# SLX_PFE_0003_IDLE_OVER_ENGINETIME                   0.0
# SLX_PFE_0004_UREA_OVER_FUEL                         0.0
# SLX_PFE_0005_CLUTCH_OVER_MILEAGE                    0.0
# SLX_PFE_0006_PARK_OVER_MILAGE                       0.0
# SLX_PFE_0007_PCT_DISTANCE_IN_AUTOMATIC_MODE         0.0
# SLX_PFE_0008_NBR_OF_GEARSHIFTS                      0.0
# SLX_PFE_0009_PCT_TOP_GEAR                           0.0
# LX_PSC_P1BBY_TOTAL_FUEL_CONSUMPTION                 0.0
# VFE_0005_VEHICLE_OPERATION_DIGIT1                   0.0
# VFE_0008_HAS_PTO                                    0.0
# SX_PSC_P1AQ6_ENTERED_LIMPHOME_MODE                  0.0
# VAR_DAX_AXLE_ARRANGEMENT                            0.0
# COUNTRY_OF_OPERATION                                0.0
# VAR_7MA_FRONT_AXLE_TYPE                             0.0
# VAR_DPX_ENGINE_TYPE                                 0.0
# VAR_T1X_PTO_ENGINE_MOUNTED_REAR                     0.0
# VAR_4DX_FRONT_BUMPER                                0.0
# VAR_F1X_REAR_AXLE_LOAD                              0.0
# VAR_FTX_GROUND_CLEARANCE_FA                         0.0
# VAR_CKX_VEHICLE_PROFILE                             0.0
# VAR_KTX_ENGINE_EMISSION_CONTROL                     0.0
# VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP                 0.0
# SX_PSC_P1AQ0_ENTERED_KICKDOWN_MODE                  0.0
# SX_PSC_P1AQ8_ENTERED_NO_SPEED_MODE                  0.0
# VAR_YLX_REAR_SUSPENSION_SYSTEM                      0.0
# SLX_PSC_P1EVS_CLUTCH_PLATE_WEAR                     0.0
# SLX_PSC_P1ATE_MAIN_LOG_IDLE_TIME                    0.0
# SLX_PSC_P1ATH_MAIN_LOG_PTO_TIME                     0.0
# SLX_PSC_P1ATJ_MAIN_LOG_VTC_ENGINE_SPEED_TIME        0.0
# SLX_PSC_P1ATN_MAIN_LOG_VTC_ENGINE_SPEED_FUEL        0.0
# SLX_PSC_P1BB0_TOTAL_ENGINE_TIME                     0.0
# SLX_PSC_P1BBX_TIME_IN_TOP_GEAR                      0.0
# SLX_PSC_P1BBY_TOTAL_FUEL_CONSUMPTION                0.0
# SLX_PSC_P1E0O_TOTAL_NUMBER_OF_PARK_BRAKE_MAN        0.0
# SLX_PSC_P1E0P_TOTAL_NUMBER_OF_AUTOMATIC_PARK        0.0
# SLX_PSC_P1E0Q_TOTAL_NUMBER_OF_AUTOMATIC_PARK        0.0
# SLX_PSC_P1E8Y_TOTAL_NUMBER_OF_PARK_BRAKE_APP        0.0
# SLX_PSC_P1FXC_UREA_SYSTEM_ERROR_COUNT_LOG           0.0
# SX_PSC_P1AQ9_ENTERED_FAULTY_GEARBOX_MODE            0.0
# SLX_PSC_P1FY7_TOP_GEAR_1_MODE_TOTAL_DISTANCE        0.0
# SLX_PSC_P1IPV_INJECTED_UREA_TOTAL_MASS              0.0
# SLX_PSC_P1IPX_TOTAL_INJECTED_UREA__L                0.0
# SLX_PSC_P1ITX_FUEL_CONSUMPTION_DURING_MOVING        0.0
# SLX_PSC_P1JR3_AUTOMATIC_SULPHUR_FUEL_REGENER        0.0
# SLX_PST_P1E1E_813_OPERATION_TIME                    0.0
# SLX_TOTAL_VEHICLE_DISTANCE_RULE_BASED               0.0
# SX_PSC_P1ITY_NUMBER_OF_PARKED_REGENERATIONS         0.0
# SX_PSC_P1ITW_FUEL_CONSUMPTION_DURING_PARKED         0.0
# SX_PSC_P1ARA_ENTERED_DYNAMOMETER_MODE               0.0
# SX_PSC_P1AQS_KICKDOWN_MODE_TIME                     0.0
# VAR_QCX_TOPOGRAPHY                                  0.0
# VAR_DKX_GROSS_COMBINATION_WEIGHT                    0.0
# SLX_PSC_P1ASV_MAIN_LOG_DRIVE_TIME                   0.0
# VAR_DHX_ROAD_CONDITION                              0.0
# VAR_FZX_FRONT_AXLE_ARRANGEMENT                      0.0
# VAR_V6X_RETARDER                                    0.0
# VAR_K4C_VEHICLE_UPTIME_SETTINGS                     0.0
# VAR_0RA_REGENERATION_CONTROLS_DPF                   0.0
# VAR_YKX_FRONT_SUSPENSION_SYSTEM                     0.0
# VAR_T3X_PTO_ENGINE_REAR_MOUNTED                     0.0
# VAR_PJX_ALTERNATOR_CAPACITY                         0.0
# VAR_41X_PARKING_HEATER                              0.0
# VAR_D7C_WHOLE_VEHICLE_TYPE_APPROVAL                 0.0
# VAR_5JB_TELEMATICS_COMMUNICAT_GATEWAYS              0.0
# VAR_RWX_TRANSMISSION                                0.0
# VAR_2EX_CAB_TILT_PUMP                               0.0
# VAR_LKX_DRIVER_STATE_SENSING_SYSTEM                 0.0
# VAR_D9C_EMISSION_LEVEL                              0.0
# VAR_DDX_CHASSIS_TYPE                                0.0
# VAR_O8A_ENGINE_PTO_TORQUE_CAPACITY                  0.0
# VAR_33A_CAB_HEIGHT                                  0.0
# VAR_J2A_ACTIVE_STEERING                             0.0
# VAR_N9C_ADR_CLASSIFICATION                          0.0
# VFE_0001_HORSE_POWER                                0.0
# VFE_0002_GROSS_COMBINATION_WEIGHT_BIN               0.0
# VFE_0003_ENGINE_GENERATION                          0.0
# VFE_0004_REAR_AXLE_LOAD_BIN                         0.0
# VFE_0005_REAR_AXLE_RATIO_BIN                        0.0
# VAR_QWX_TURBO                                       0.0
# VAR_7NA_FRONT_SUSPENSION_INSTALLATION               0.0
# VAR_2RB_BATTERY_MAINTENANCE                         0.0
# VAR_RUX_GEAR_SHIFTING_SYSTEM                        0.0
# VAR_FAX_STEERING_WHEEL_POS                          0.0
# VAR_2CX_CAB_VERSION                                 0.0
# VAR_2DX_REAR_CAB_SUSPENSION                         0.0
# VAR_GSX_CHASSIS_HEIGHT                              0.0
# VAR_FFX_PUSHER_AXLE_FEATURES                        0.0
# VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE                   0.0
# VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR                   0.0
# VAR_5NX_ENGINE_BLOCK_HEATER                         0.0
# VAR_TAX_REAR_AXLE_RATIO                             0.0
# VAR_A3A_IDLE_SHUTDOWN                               0.0
# VAR_2LX_FRONT_CAB_SUSPENSION                        0.0
# VAR_U3X_BRAKE_FRONT                                 0.0
# VAR_7PX_HYDRAULIC_PUMP_GEARBOX_MOUNTED              0.0
# VAR_T4X_PTO_TRANSM_MOUNTED                          0.0
# VAR_UBX_HYDRAULIC_PUMP_ENG_MTD                      0.0
# VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS               0.0
# VAR_REX_CRANK_CASE_VENTILATION                      0.0
# VAR_78X_TRANSPORT_CYCLE                             0.0
# VAR_T2X_TRANSMISSIONRETARDER_COOLER                 0.0
# VAR_U4X_BRAKE_DRIVE_REAR                            0.0
# VAR_FVX_FRONT_AXLE_LOAD                             0.0
# VAR_VWX_COMPRESSOR_CAPACITY                         0.0
# VAR_H1B_TURBO_APPLICATION                           0.0
# VAR_FDX_REAR_AXLE_ARRANGEMENT                       0.0
# SLX_PSC_P1ASW_MAIN_LOG_IDLE_FUEL                    0.0
# SLX_PSC_P1ASR_MAIN_LOG_CRUISE_TIME                  0.0
# X_PST_P1ENC_18_PMLININGWEARPREDICTIVEMILEAGE_       0.0
# X_PSC_P1JA8_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBI_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBH_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBG_UREA_ADAPTION_NWM_PARAMERTER_9          0.0
# X_PSC_P1JBF_UREA_ADAPTION_NWM_PARAMERTER_8          0.0
# X_PSC_P1JBE_UREA_ADAPTION_NWM_PARAMERTER_7          0.0
# X_PSC_P1JBD_UREA_ADAPTION_NWM_PARAMERTER_6          0.0
# X_PSC_P1JBC_UREA_ADAPTION_NWM_PARAMERTER_5          0.0
# X_PSC_P1JBB_UREA_ADAPTION_NWM_PARAMERTER_4          0.0
# X_PSC_P1JBA_UREA_ADAPTION_NWM_PARAMERTER_3          0.0
# X_PSC_P1JAZ_RATED_ENGINE_POWER                      0.0
# X_PSC_P1JA9_UREA_ADAPTION_NWM_PARAMERTER_2          0.0
# X_PSC_P1ITY_NUMBER_OF_PARKED_REGENERATIONS          0.0
# X_PSC_P1JBK_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1ITW_FUEL_CONSUMPTION_DURING_PARKED          0.0
# X_PSC_P1IT7_NUMBER_OF_TIMES_THE_ESTIMATED_          0.0
# X_PSC_P1IT2_AFTERTREATMENT_REGENERATION_IN          0.0
# X_PSC_P1IPW_TOTAL_USED_UREA__G                      0.0
# X_PSC_P1IPO_MINIMUM_UREA_QUALITY_MASS__AT_          0.0
# X_PSC_P1IPN_MAXIMUM_UREA_QUALITY_MASS__AT_          0.0
# X_PSC_P1IPM_UREA_QUALITY_MASS_SAVED_AT_POW          0.0
# X_PSC_P1IOY_SOOT_MASS_REPORTED_BY_KALMAN_F          0.0
# X_PSC_P1I9E_NUMBER_OF_TIMES_THE_WATER_IN_F          0.0
# X_PSC_P1HUB_SOFT_CRUISE_ENABLE                      0.0
# X_PSC_P1HTM_SOOT_LEVEL                              0.0
# X_PSC_P1JBJ_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JBL_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1F0I_ENGINE_INTAKE_AIR_MASS_FLOW_RA          0.0
# X_PSC_P1K8T_NUMBER_OF_SUCCESSIVE_INTERRUPT          0.0
# X_PST_P1EM9_16_PMAIRDRYERCARTRIDGEMONITOR_LOG       0.0
# X_PST_P1EM9_15_PMAIRDRYERCARTRIDGEPERCENTAGEW       0.0
# X_PST_P1EM9_14_PMAIRDRYERCARTRIDGEPREDICTIVEM       0.0
# X_PST_P1E1E_811_COMP_DUTY_CYCLE                     0.0
# X_PST_P1E1D_1076_MILEAGE_CARTRIDGE_N1               0.0
# X_PST_P1E1D_1075_TAV_CARTRIDGE_N1                   0.0
# X_PST_P1C3B_128_VDLRSL2NDTHRESHOLDACTIVEDISTAN      0.0
# X_PST_P1C2O_365_VDLCOMPRTOTALTIME_LOG               0.0
# X_PST_P1C2J_527_TLDRIVINGMONSYSTEMRECOMMENDEDG      0.0
# X_PSC_P1LJQ_ADBLUE_ADAPTION_FACTOR_INITIAL          0.0
# X_PSC_P1KOA_SPECIFIC_NOX_EMISSIONS_AT_EXHA          0.0
# X_PSC_P1K8S_NUMBER_OF_SUCCESSIVE_FAILED_RE          0.0
# X_PSC_P1JBM_UREA_ADAPTION_NWM_PARAMERTER_1          0.0
# X_PSC_P1JRY_AUTOMATIC_SOOT_KF_REGENERATION          0.0
# X_PSC_P1JRX_AUTOMATIC_SOOT_PM_REGENERATION          0.0
# X_PSC_P1JRW_AUTOMATIC_SOOT_TIME_REGENERATI          0.0
# X_PSC_P1JRU_AUTOMATIC_SOOT_DISTANCE_REGENE          0.0
# X_PSC_P1JRT_PARKED_SULPHUR_REGENERATION_TR          0.0
# X_PSC_P1JRQ_PARKED_SOOT_REGENERATION_TRIGG          0.0
# X_PSC_P1JR5_AUTOMATIC_SULPHUR_DPF_REGENERA          0.0
# X_PSC_P1JR2_AUTOMATIC_HC_DPF_REGENERATION_          0.0
# X_PSC_P1JR0_AUTOMATIC_CRYSTALS_REGENERATIO          0.0
# X_PSC_P1JBT_SCR_OPERATOR_INDUCEMENT_REASON          0.0
# X_PSC_P1JBN_UREA_ADAPTION_FACTOR_NWM_PARAM          0.0
# X_PSC_P1FXO_YAXIS_OF_EXHAUST_TEMPERATURE_1          0.0
# X_PSC_P1EZH_TOTAL_NUMBER_OF_TRAILER_TEST_A          0.0
# SLX_PSC_P1ASQ_MAIN_LOG_CRUISE_FUEL                  0.0
# SLX_PSC_P1AQP_POWER_MODE_DISTANCE                   0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_18        0.0
# X_PMU_P1FH1_SLOPE_X_INDEX_32                        0.0
# X_PMU_P1FH1_SLOPE_X_INDEX_1                         0.0
# AGE_MONTHS                                          0.0
# AGE_YEARS                                           0.0
# SLX_PSC_P1APL_CLUTCH_TIME_DISENGAGED                0.0
# SLX_PSC_P1APU_CLUTCH_NUMBER_DISENGAGES              0.0
# SLX_PSC_P1AQ1_LEVER_MOVED_FROM_AUTO_TO_MAN          0.0
# SLX_PSC_P1AQ7_ENTERED_BACKUP_MODE                   0.0
# SLX_PSC_P1AQE_GEARBOX_MOVEMENT_GEAR1R_GEARR         0.0
# SLX_PSC_P1AQG_GEARBOX_MOVEMENT_GEAR23_GEAR2         0.0
# SLX_PSC_P1AQQ_POWER_MODE_FUEL                       0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_20        0.0
# SLX_PSC_P1AQR_BRAKE_MODE_TIME                       0.0
# SLX_PSC_P1AQU_ECOROLL_ACTIVE_TIME                   0.0
# SLX_PSC_P1AQX_ENTERED_ECONOMY_MODE                  0.0
# SLX_PSC_P1AQY_ENTERED_POWER_MODE                    0.0
# SLX_PSC_P1AQZ_ENTERED_BRAKE_MODE                    0.0
# SLX_PSC_P1ARB_ECONOMY_MODE_TIME                     0.0
# SLX_PSC_P1ARL_BRAKE_MODE_DISTANCE                   0.0
# SLX_PSC_P1ARN_CLUTCH_NUMBER_SLIP_ABUSE              0.0
# SLX_PSC_P1AS4_MAIN_LOG_ECON_DISTANCE                0.0
# SLX_PSC_P1AS6_MAIN_LOG_PTO_DISTANCE                 0.0
# SLX_PSC_P1AS9_MAIN_LOG_BRAKE_TIME                   0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_X_INDEX_19        0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_18        0.0
# X_PSC_P1EII_WFACTOR                                 0.0
# X_PSC_P1ATP_OIL__DEGRADATION_DISTANCE_STAR          0.0
# X_PSC_P1E0I_AIR_PRODUCTION_MODULATOR_CARTR          0.0
# X_PSC_P1E09_VEHICLE_AIR_LEAKAGE_ESTIMATED           0.0
# X_PSC_P1C04_VEHICLE_WEIGHT_WITH_TRAILER_ME          0.0
# X_PSC_P1BVS_IDLE_SHUTDOWN_IDLE_TIMER_VALUE          0.0
# X_PSC_P1B99_AIR_PRODUCTION_MODULATOR_TOTAL          0.0
# X_PSC_P1ATX_OIL_STATUS                              0.0
# X_PSC_P1ATW_OIL_QUALITY                             0.0
# X_PSC_P1ATV_OIL_LIFE_AT_PAST_DUE                    0.0
# X_PSC_P1ATS_OIL_DEGRADATION_LAST_OLC_HOURS          0.0
# X_PSC_P1ATR_OIL_DEGRADATION_LAST_OLC_DISTA          0.0
# X_PSC_P1ATQ_OIL__DEGRADATION_HOURS_START            0.0
# X_PSC_P1ARM_KICKDOWN_MODE_DISTANCE                  0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_19        0.0
# X_PSC_P1ARA_ENTERED_DYNAMOMETER_MODE                0.0
# X_PSC_P1AQS_KICKDOWN_MODE_TIME                      0.0
# X_PSC_P1AQ9_ENTERED_FAULTY_GEARBOX_MODE             0.0
# X_PSC_P1AQ8_ENTERED_NO_SPEED_MODE                   0.0
# X_PSC_P1AQ6_ENTERED_LIMPHOME_MODE                   0.0
# X_PSC_P1AQ0_ENTERED_KICKDOWN_MODE                   0.0
# X_PSC_P1AOD_DIFF_RSL_MAX_VSPD_NEXT_HIGHEST          0.0
# X_PSC_P1AL0_DIFFERENTIATED_RSL_ENABLE               0.0
# X_PSC_P1AFR_OUTDOOR_TEMPERATURE                     0.0
# X_PSC_MI_ENABLE_IMMOBILISER                         0.0
# X_PMU_P1FWM_ENGINE_SPEED_TORQUE_H_Y_INDEX_20        0.0
# DAY                                                 0.0
# dtype: float64

# %% [markdown]
# ## Category Pipeline

# %%
# Date transformation
#data = extraTrasfromToCategory(data, debug=True)

'''
# Zero Variance removal
data = removeZeroCategory(data)
print ('After all removal pipeline - ',data.shape)
'''
# Out:
# "\n# Zero Variance removal\ndata = removeZeroCategory(data)\nprint ('After all removal pipeline - ',data.shape)\n"

# %%
'''# First time 
# find all categorical features.
data_cat = data.select_dtypes(include='object')
cat_features_df = embeddingSizeExtract(data_categorical=data_cat)
cat_features_df

# save this embedding dataframe information to a csv file
cat_features_df.to_csv("drive/My Drive/Thesis/data/Embedding_Data/cat_embedding_details.csv", sep=',', index=False)
'''
# load this information from the save csv file
cat_features_df = pd.read_csv("drive/My Drive/Thesis/data/Embedding_Data/cat_embedding_details.csv", sep=',', low_memory=False)

# %%
cat_features_df
# Out:
#                                    Feature  Cardinality  Embedding_Size
# 0                                      DAY            2               1
# 1                                    MONTH           12               6
# 2                                     YEAR            4               2
# 3                  VAR_7MA_FRONT_AXLE_TYPE            2               1
# 4                      VAR_DPX_ENGINE_TYPE            3               2
# 5          VAR_T1X_PTO_ENGINE_MOUNTED_REAR            2               1
# 6                     VAR_4DX_FRONT_BUMPER            3               2
# 7                   VAR_F1X_REAR_AXLE_LOAD           15               8
# 8              VAR_FTX_GROUND_CLEARANCE_FA            5               3
# 9                  VAR_CKX_VEHICLE_PROFILE            2               1
# 10         VAR_KTX_ENGINE_EMISSION_CONTROL            2               1
# 11     VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP            5               3
# 12                      VAR_QCX_TOPOGRAPHY            3               2
# 13          VAR_YLX_REAR_SUSPENSION_SYSTEM            2               1
# 14        VAR_DKX_GROSS_COMBINATION_WEIGHT           11               6
# 15             VAR_2RB_BATTERY_MAINTENANCE            2               1
# 16              VAR_FAX_STEERING_WHEEL_POS            2               1
# 17                     VAR_2CX_CAB_VERSION            5               3
# 18             VAR_2DX_REAR_CAB_SUSPENSION            2               1
# 19                  VAR_GSX_CHASSIS_HEIGHT            6               3
# 20            VAR_FFX_PUSHER_AXLE_FEATURES            3               2
# 21       VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE            3               2
# 22       VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR            2               1
# 23             VAR_5NX_ENGINE_BLOCK_HEATER            2               1
# 24                 VAR_TAX_REAR_AXLE_RATIO           24              10
# 25                   VAR_A3A_IDLE_SHUTDOWN            2               1
# 26            VAR_2LX_FRONT_CAB_SUSPENSION            2               1
# 27            VAR_RUX_GEAR_SHIFTING_SYSTEM            3               2
# 28                     VAR_U3X_BRAKE_FRONT            3               2
# 29              VAR_T4X_PTO_TRANSM_MOUNTED            2               1
# 30          VAR_UBX_HYDRAULIC_PUMP_ENG_MTD            2               1
# 31   VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS            3               2
# 32          VAR_REX_CRANK_CASE_VENTILATION            3               2
# 33                 VAR_78X_TRANSPORT_CYCLE            3               2
# 34     VAR_T2X_TRANSMISSIONRETARDER_COOLER            2               1
# 35                VAR_U4X_BRAKE_DRIVE_REAR            3               2
# 36                 VAR_FVX_FRONT_AXLE_LOAD            8               4
# 37             VAR_VWX_COMPRESSOR_CAPACITY            3               2
# 38                VAR_DAX_AXLE_ARRANGEMENT            6               3
# 39               VAR_H1B_TURBO_APPLICATION            2               1
# 40           VAR_FDX_REAR_AXLE_ARRANGEMENT            7               4
# 41  VAR_7PX_HYDRAULIC_PUMP_GEARBOX_MOUNTED            2               1
# 42   VAR_7NA_FRONT_SUSPENSION_INSTALLATION            4               2
# 43     VAR_LKX_DRIVER_STATE_SENSING_SYSTEM            2               1
# 44                           VAR_QWX_TURBO            2               1
# 45          VAR_FZX_FRONT_AXLE_ARRANGEMENT            2               1
# 46                        VAR_V6X_RETARDER            2               1
# 47         VAR_K4C_VEHICLE_UPTIME_SETTINGS            3               2
# 48       VAR_0RA_REGENERATION_CONTROLS_DPF            4               2
# 49         VAR_YKX_FRONT_SUSPENSION_SYSTEM            2               1
# 50         VAR_T3X_PTO_ENGINE_REAR_MOUNTED            2               1
# 51             VAR_PJX_ALTERNATOR_CAPACITY            3               2
# 52                  VAR_41X_PARKING_HEATER            4               2
# 53     VAR_D7C_WHOLE_VEHICLE_TYPE_APPROVAL            2               1
# 54  VAR_5JB_TELEMATICS_COMMUNICAT_GATEWAYS            2               1
# 55                    VAR_RWX_TRANSMISSION            8               4
# 56                  VAR_DHX_ROAD_CONDITION            2               1
# 57                   VAR_2EX_CAB_TILT_PUMP            2               1
# 58                  VAR_D9C_EMISSION_LEVEL            4               2
# 59                    VAR_DDX_CHASSIS_TYPE            2               1
# 60      VAR_O8A_ENGINE_PTO_TORQUE_CAPACITY            3               2
# 61                      VAR_33A_CAB_HEIGHT            7               4
# 62                 VAR_J2A_ACTIVE_STEERING            2               1
# 63              VAR_N9C_ADR_CLASSIFICATION            4               2
# 64                    VFE_0001_HORSE_POWER            3               2
# 65   VFE_0002_GROSS_COMBINATION_WEIGHT_BIN            3               2
# 66              VFE_0003_ENGINE_GENERATION            3               2
# 67             VFE_0004_REAR_AXLE_LOAD_BIN           11               6
# 68            VFE_0005_REAR_AXLE_RATIO_BIN           16               8
# 69                      VFE_0009_LTVF_TYPE            6               3
# 70       VFE_0005_VEHICLE_OPERATION_DIGIT1            5               3
# 71       VFE_0006_VEHICLE_OPERATION_DIGIT2            9               5
# 72                     VFE_0007_CAB_HEIGHT            7               4
# 73                        VFE_0008_HAS_PTO            2               1

# %%
data.shape
# Out:
# (19954, 447)

# %% [markdown]
# (336677, 449)

# %% [markdown]
# # Training and Validation Data Extraction
# Based on the previous understanding. We are going to have to nature of data
# - Numerical Features and Catgorical Features.
# The Numerical features have a total of 362 features while the Categorical feature has 74 features.
#
# We will have Training and Validation data.

# %%
'''
# extracting the categorical features
# extracting the categorical features
cat_features = cat_features_df['Feature'].values
# numerical features are
num_features = data.select_dtypes(exclude='object').columns

# create a dataframe of the numerical and categorical features and store the result
feature_names_cat = pd.DataFrame(data=None)
feature_names_num = pd.DataFrame(data=None)
feature_names_num['Numerical'] = num_features
feature_names_cat['Categorical'] = cat_features

# save this feature names of categorical and numerical features to a csv files
feature_names_cat.to_csv("drive/My Drive/Thesis/data/Embedding_Data/feature_names_cat.csv", sep=',', index=False)
# save this feature names of categorical and numerical features to a csv files
feature_names_num.to_csv("drive/My Drive/Thesis/data/Embedding_Data/feature_names_num.csv", sep=',', index=False)
'''
# load feature names from db
feature_names_cat = pd.read_csv("drive/My Drive/Thesis/data/Embedding_Data/feature_names_cat.csv", sep=',', low_memory=False)
feature_names_num = pd.read_csv("drive/My Drive/Thesis/data/Embedding_Data/feature_names_num.csv", sep=',', low_memory=False)

# %%
# fetch the categorical and numerical features
cat_features = feature_names_cat['Categorical'].values
num_features = feature_names_num['Numerical'].values

# %%
features = list(cat_features)
features.append('T_CHASSIS')

# %%
data = data[features].dropna()

# %%
from sklearn.model_selection import train_test_split, GroupShuffleSplit
# for cross validation, we can use Group KFold spliting - GroupShuffleSplit

# %%
# Function for assisting in spliting the data
def validationSplit(data_in, split=0.2, toShuffle=False):
  # here we will split the data
  # splitting by chassis
  chassis_data = data_in['T_CHASSIS'].unique()
  # splitting the chassis data
  c_train, c_val = train_test_split(chassis_data, test_size=split, random_state=42, shuffle=toShuffle)
  # extracting out the training and testing
  train_data = data_in[data_in['T_CHASSIS'].isin(c_train)].reset_index(drop=True)
  test_data = data_in[data_in['T_CHASSIS'].isin(c_val)].reset_index(drop=True)
  return train_data, test_data

# %%
# Function for assisting in spliting the data
def crossValidationSplit(data_in, split=0.2, toShuffle=False):
  # here we will split the data based on their chassis grouping
  chassis_group = data['T_CHASSIS'].values
  ## generating the Group Parameters
  c_split = GroupShuffleSplit(n_splits=2, test_size=0.2, random_state=42)
  '''
  # splitting the data
  for train_idx, test_idx in c_split.split(data.values, groups=chassis_group):
    print("TRAIN:", data.values[train_idx].shape, "TEST:", data.values[test_idx].shape)
  '''
  return c_split

# %% [markdown]
# ### Train Splitting

# %%
#data_t.to_csv("drive/My Drive/Thesis/data/Embedding_Data/chassis_training_data.csv", sep=',', index=False)
#data_v.to_csv("drive/My Drive/Thesis/data/Embedding_Data/chassis_testing_data.csv", sep=',', index=False)

data_t, data_v = validationSplit(data, split=0.2)
data_t.shape, data_v.shape
# Out:
# ((16131, 75), (3823, 75))

# %% [markdown]
# ## Category Summary
# In summary, we have a total of 74 categories. They can be used to filter new data sources instead of going through the whole extaction and category pipeline all over again.

# %% [markdown]
# ## Handling numerical features
# We have a total of 362 numerical features

# %% [markdown]
# ## Embeddings

# %% [markdown]
# In order to apply embeddings for out categorical variables. We need to first determine which features are categorical variable and which are not. We need to ensure we caputure all possible cases of the categorical features.
#
# Okay, then for each categorical variable we need to capture the cardinalty of the feature iteself.

# %%
# use tensorflow version 2
# %tensorflow_version 2.x

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, Input, Reshape, Concatenate, Dense, Flatten, Dropout

from tensorflow.keras.callbacks import TensorBoard
import os
import datetime

from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

# %%
#from tensorflow.summary import create_file_writer
#  TensorFlow and the TensorBoard HParams plugin:
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
### Write metadata file for embeddings
def write_metadata(filename, labels):
    """
            Create a metadata file image consisting of sample indices and labels
            :param filename: name of the file to save on disk
            :param shape: tensor of labels
    """
    with open(filename, 'w') as f:
        f.write("Index\tLabel\n")
        for index, label in enumerate(labels):
            f.write("{}\t{}\n".format(index, label))

    print('Metadata file saved in {}'.format(filename))

# %%
#data_t[cat_features].nunique()

# %%
feature_col_labels = pd.factorize(data_t.loc[:, 'VFE_0007_CAB_HEIGHT'].values)[0]
metadata_path = "drive/My Drive/Thesis/data/Embedding_Data/metadata_CAB_HEIGHT.tsv"
#write_metadata(metadata_path, feature_col_labels)

# %%
embeddings_meta = {'Embedding_layer_VFE_0007_CAB_HEIGHT':metadata_path}

# %% [markdown]
# ### Saving and Loading Embeddings

# %%
# Goal
'''
Write a function, when given a categorical variable, it will generate the vector representation for that variable.
In order to achieve that, we first need to map very categorical variable to some numerical index value. This value 
has to be unique and not random. 
'''

def transfromForEmbed(data_cat, cat_feature_name='', cat_mapping=''):
  # find the cat_index for all the features
  def findCatIndex(x):
    return int(cat_mapping[cat_mapping[cat_feature_name] == x][cat_feature_name+'_index'].values[0])
  output = data_cat[cat_feature_name].apply(findCatIndex) 
  return output

def embedTransform(model=None, variable='', cat_feature_name='', cat_mapping='', return_type=1):
  # Given a categorical variable, produce the embedded vector
  # Find the index of the categorical variable in the cat_mapping dataframe
  cat_index = int(cat_mapping[cat_mapping[cat_feature_name] == variable][cat_feature_name+'_index'].values[0])
  if return_type == 0:
    return cat_index
  # fetch the embeddings weights
  pre_embedding = "Embedding_layer_"
  embed_layer = model.get_layer(name=pre_embedding+cat_feature_name)
  embedd_vector = embed_layer.get_weights()[0][cat_index]
  return embedd_vector

def createCatMapping(data_cat):
  # this function will create a mapping dataframe
  cat_size = data_cat.shape[1]
  feature_names = data_cat.columns

  cat_mapping = pd.DataFrame()

  col_mapping_list = list()
  col_mapping_cols = list()
  # try for all dataframes
  for i in range(cat_size):
    col_indexs = list(pd.factorize(data_cat.iloc[:, i].unique())[0])
    # save to list
    col_mapping_list.append(list(data_cat.iloc[:, i].unique()))
    col_mapping_list.append(col_indexs)
    # save the column name as well
    col_mapping_cols.append(feature_names[i])
    col_mapping_cols.append(feature_names[i]+'_index')

  # now we need to save the list to a dataframe
  cat_mapping = pd.DataFrame(col_mapping_list)
  # transpose it
  cat_mapping = cat_mapping.transpose()
  # update the columns names
  cat_mapping.columns = col_mapping_cols

  # save to the dataframe
  cat_mapping.to_csv("drive/My Drive/Thesis/data/Embedding_Data/cat_mappings.csv", sep=',', index=False)

#createCatMapping(data[cat_features])

# %%
# load from file
cat_mappings = pd.read_csv("drive/My Drive/Thesis/data/Embedding_Data/cat_mappings.csv", sep=',', low_memory=False)

# %%
# load the embedding model
from tensorflow.keras.models import load_model
# identical to the previous one
embed_model3 = load_model("drive/My Drive/Thesis/data/Embedding_Data/embedding_model_low_mae.h5")

# %%
# find the embedding vector for feature CABH210 in VFE_0007_CAB_HEIGHT
'''
my_vector1 = embedTransform(embed_model, variable='CABH175', cat_feature_name='VFE_0007_CAB_HEIGHT', cat_mapping=cat_mappings)
my_vector2 = embedTransform(embed_model, variable='CABH165', cat_feature_name='VFE_0007_CAB_HEIGHT', cat_mapping=cat_mappings)
my_vector3 = embedTransform(embed_model, variable='CABH210', cat_feature_name='VFE_0007_CAB_HEIGHT', cat_mapping=cat_mappings)
my_vector4 = embedTransform(embed_model, variable='CABH230', cat_feature_name='VFE_0007_CAB_HEIGHT', cat_mapping=cat_mappings)
my_vector5 = embedTransform(embed_model, variable='Low', cat_feature_name='VFE_0007_CAB_HEIGHT', cat_mapping=cat_mappings)
'''
'''
x1 = output_embeddings[0]
x2 = output_embeddings[1]

# calculating the cosing similarity of two vectors in the orginal space
a_dot = np.dot(x1, x2)
similar = a_dot / (np.linalg.norm(x1) * np.linalg.norm(x2))
similar
'''
# Out:
# '\nx1 = output_embeddings[0]\nx2 = output_embeddings[1]\n\n# calculating the cosing similarity of two vectors in the orginal space\na_dot = np.dot(x1, x2)\nsimilar = a_dot / (np.linalg.norm(x1) * np.linalg.norm(x2))\nsimilar\n'

# %%
# betwen CABH175 and CABH165, i have 0.867487
# betwen CABH175 and CABH210, i have 0.11280868
# betwen CABH175 and CABH230, i have -0.5284594
# betwen CABH175 and Low, i have -0.36939222

# %% [markdown]
# ### Creating the Keras Embeddings

# %%
### Creating the Keras Embeddings Mode

def create_model(saved_model=None):
  # IDs representing 1-hot encodings
  # Need to create the input for all features
  cat_embedding_input_layers = []

  cat_reshape_layers = []
  # Embeddings for the first cat feature
  id_feature = 0
  # create an array of embeddings layers
  cat_embedding_layers = []

  # interate through categorical varaibles
  for id_feature in range(cat_features_df.shape[0]):
    # creating the input layer for the embeddings
    #input_layer = Input(shape=(1,), name="Input_layer_"+cat_features_df.loc[id_feature, 'Feature'])
    input_layer = Input(shape=(1,), name="Input_layer_"+cat_features_df.loc[id_feature, 'Feature'])
    cat_embedding_input_layers.append(input_layer)
    # embedding size 
    layer_embedding_size = cat_features_df.loc[id_feature, 'Embedding_Size']
    # create the embedding layers
    embed_weights = saved_model.get_layer(name="Embedding_layer_"+cat_features_df.loc[id_feature, 'Feature']).get_weights()
    #embedded_layer.trainable = False
    embedded_layer = Embedding(input_dim=cat_features_df.loc[id_feature, 'Cardinality'], output_dim=layer_embedding_size, 
                               name="Embedding_layer_"+cat_features_df.loc[id_feature, 'Feature'], input_length = 1, trainable=False, weights=embed_weights)(input_layer)
    cat_embedding_layers.append(embedded_layer)
    # add a reshape of the embedding layers
    reshape_layer = Reshape(target_shape=(layer_embedding_size,))(embedded_layer)
    # appends the rehshape models together
    cat_reshape_layers.append(reshape_layer)

  ### Create A combined embedding layers only
  combined_emb = Concatenate(axis=1, name='combined_embeddings')(cat_reshape_layers)
  
  ### the output of the combine embedding model is 169 vectors

  ### creating a model based on the trained weights
  model_emb = Model(inputs=cat_embedding_input_layers, outputs=combined_emb, name="Categorical_Embeddings")

  # compile the model - for a regression model
  model_emb.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])
  # compile the model - for a classification problem
  # model.compile(loss='binary_crossentropy', optimizer='adam')
  return model_emb

def train_model(model, x_train, y_train, x_test, y_test, epochs, batch_size, early_stop_callback=None, tensorboard_callback=None):
  # fitting the model
  #model.fit(x=x_train, y=y_train, epochs=epochs, batch_size=batch_size, verbose=2, validation_data=(XTest, yTest), callbacks=[early_stop, tensorboard_callback])
  model.fit(x=x_train, y=y_train, epochs=epochs, batch_size=batch_size, verbose=2, callbacks=[early_stop_callback, tensorboard_callback])
  return model

# %%
## For each run, log an hparams summary with the hyperparameters and final accuracy:
def run(my_model, x_train, y_train, epochs, batch_size, early_stop_callback, tensorboard_log):
  model = None
  model = create_model(my_model)
  model_output = train_model(model, x_train, y_train, epochs, batch_size, early_stop_callback=early_stop_callback, tensorboard_callback=tensorboard_log)
  # do something with the metrics
  return model_output

# %%
# plot the model
#plot_model(model=model_emb, to_file='drive/My Drive/Thesis/data/Embedding_Data/model_image.png', show_shapes=True, dpi=300)
#plot_model(model=model_emb, to_file='drive/My Drive/Thesis/data/Embedding_Data/model_new.png', show_shapes=True, dpi=300)

# %% [markdown]
# ## Inputs to the Network
#
# We need to create a list of inputs, such that each categorical feature has it's own list of values and the last list will be a 2D array of the continous values. As shown above.
#
# The size of the list of inputs : ip = n_cat + 1
#
# Remember for each of the embedding network we had set input-size =1 we are taking 1 value each from all the list (except the last list) and sending it to the combined network for training. For the last list, each value itself is a list having the other columns values, and this is sent to the models_rest network

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler

# %%
def transfromForEmbed(data_cat, cat_feature_name='', cat_mapping='', type=None):
  # find the cat_index for all the features
  def findCatIndex(x):
    return int(cat_mapping[cat_mapping[cat_feature_name] == x][cat_feature_name+'_index'].values[0])
  if type is not None:
    output = findCatIndex(data_cat[cat_feature_name])
    return np.array([output])
  else:
    output = data_cat[cat_feature_name].apply(findCatIndex) 
    return output.values

# function to reformat the input data into the necessary input data for our network to be trained on.
def network_input_process(data_num=None, data_cols=None, y_output=None, input_type=1):
  # create a list of inputs. 
  try:
    cat_size = data_cols.shape[1]
    columns_name = data_cols.columns
    col_type = None
  except:
    cat_size = data_cols.shape[0]
    columns_name = data_cols.index
    col_type = 1

  # define the size of the network list inputs
  network_inputs = [None] * (cat_size)

  # add inputs to the list
  # for the categorical inputs

  for i in range(cat_size):
    #network_inputs[i] = pd.factorize(data_cols.iloc[:, i].values)[0]
    # map each categorical variable to their respective index values
    #print (columns_name[i])
    #network_inputs[i] = transfromForEmbed(data_cols, cat_feature_name=columns_name[i], cat_mapping=cat_mappings, type=col_type)
    network_inputs[i] = data_cols.loc[:, columns_name[i]].values

  return network_inputs, y_output.values

# %%
'''
data_embed = network_input_process(data_num=None, data_cols=data[cat_features], y_output=None)
data_embed = np.array(data_embed).transpose()
data_embed.shape
# create a new pandas dataframe with this embedding encoding
new_data = copy.copy(data)
new_data.loc[:, list(cat_features)] = data_embed
# save to db
new_data.to_csv("drive/My Drive/Thesis/data/Embedding_Data/v2_sorted_data_new.csv", sep=',', index=False)
'''
# Out:
# '\ndata_embed = network_input_process(data_num=None, data_cols=data[cat_features], y_output=None)\ndata_embed = np.array(data_embed).transpose()\ndata_embed.shape\n# create a new pandas dataframe with this embedding encoding\nnew_data = copy.copy(data)\nnew_data.loc[:, list(cat_features)] = data_embed\n# save to db\nnew_data.to_csv("drive/My Drive/Thesis/data/Embedding_Data/v2_sorted_data_new.csv", sep=\',\', index=False)\n'

# %%
# creating the training inputs
scaler = RobustScaler()
# scale and fit
#scaler.fit(data_t.loc[:, num_features].values)
#data_t.loc[:, num_features] = scaler.transform(data_t.loc[:, num_features].values)
#data_v.loc[:, num_features] = scaler.transform(data_v.loc[:, num_features].values)

# create the requirment for the embedding model
XTrain, yTrain = network_input_process(data_num=None, data_cols=data[cat_features], y_output=data.iloc[:,3])

# %%
XTrain[10].shape
# Out:
# (19954,)

# %% [markdown]
# ## Embedding Model

# %%
#fetch our the trained embedding model the model
model_embeddings = None
model_embeddings = create_model(saved_model=embed_model3)

# %%
model_embeddings.fit(XTrain, yTrain, epochs=1, workers=-1)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-50-39e14c776884> in <module>()
# ----> 1 model_embeddings.fit(XTrain, yTrain, epochs=1, workers=-1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     642         # Lifting succeeded, so variables are initialized and we can run the
#     643         # stateless function.
# --> 644         return self._stateless_fn(*args, **kwds)
#     645     else:
#     646       canon_args, canon_kwds = \
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# UnimplementedError:  Cast string to float is not supported
# 	 [[node Categorical_Embeddings/Cast_3 (defined at <ipython-input-50-39e14c776884>:1) ]] [Op:__inference_train_function_18089]
#
# Function call stack:
# train_function

# %%
# Embedding Prediction
embed_data = model_embeddings.predict(XTrain)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-48-d5b20585c1ed> in <module>()
#       1 # Embedding Prediction
# ----> 2 embed_data = model_embeddings.predict(XTrain)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1266           for step in data_handler.steps():
#    1267             callbacks.on_predict_batch_begin(step)
# -> 1268             tmp_batch_outputs = predict_function(iterator)
#    1269             # Catch OutOfRangeError for Datasets of unknown size.
#    1270             # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     648               *args, **kwds)
#     649       # If we did not create any variables the trace we have is good enough.
# --> 650       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     651
#     652     def fn_with_cond(*inner_args, **inner_kwds):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# UnimplementedError:  Cast string to float is not supported
# 	 [[node Categorical_Embeddings/Cast_3 (defined at <ipython-input-48-d5b20585c1ed>:2) ]] [Op:__inference_predict_function_12377]
#
# Function call stack:
# predict_function

# %% [markdown]
# ## AutoEncoders Training and Testing Data

# %%
# now I need to be able to split the embed predictions by chassis wise
data_embed = pd.DataFrame(embed_data)
# add chassis information as well
data_embed['T_CHASSIS'] = data['T_CHASSIS'].values
data_embed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-91920b26b6b6> in <module>()
#       1 # now I need to be able to split the embed predictions by chassis wise
# ----> 2 data_embed = pd.DataFrame(embed_data)
#       3 # add chassis information as well
#       4 data_embed['T_CHASSIS'] = data['T_CHASSIS'].values
#       5 data_embed
#
# NameError: name 'embed_data' is not defined

# %%
# I can decide to save the embedds if I want to
#data_embed.to_csv("drive/My Drive/Thesis/data/Embedding_Data/sorted_data_full_embeds.csv", sep=',', index=False)

# %%
# Split embedding data based on Chassis information
train_embed, test_embed = validationSplit(data_embed, split=0.2)
# extract train and test data
XTrain_embed = train_embed.iloc[:, :169].values
XTest_embed = test_embed.iloc[:, :169].values

# %% [markdown]
# ### Building the AutoEncoder models

# %%
from tensorflow.keras.layers import PReLU, ReLU, BatchNormalization, ELU
from keras.initializers import Constant
from keras import regularizers

# %%
### Good AE model
# 169 --> 85 --> 169
# Using PReLu activation. getting training accuracy of 91% and val accuracy of 89%

# %%
# create the encoder model
'''
input_encoder = Input(shape=(169,), name="encoder_input_layer")
# create the first encoder layer
#encoder_layer1 = Dense(units=85, name='encoder_layer1', activity_regularizer=regularizers.l1(10e-5))(input_encoder)
encoder_layer1 = Dense(units=11, name='encoder_layer1', )(input_encoder)

layer_1 = PReLU(alpha_initializer=Constant(value=0.3))(encoder_layer1)
#layer_1 = ELU()(encoder_layer1)

encoder = Model(inputs=input_encoder, outputs=layer_1, name='Encoder_Model')

# Create the Decoder model
input_decoder = Input(shape=(2,), name="Decoder_input_layer")
# decoder 2nd decoder layer
decoder_layer1 = Dense(units=169, name='decoder_layer1')(layer_1)
layer_2 = PReLU(alpha_initializer=Constant(value=0.3))(decoder_layer1)
#layer_2 = ELU()(decoder_layer1)

#decoder = Model(inputs=input_decoder, outputs=decoder_layer1)

# create the AE model
autoencoder = Model(inputs=input_encoder, outputs=layer_2, name="AutoEncoder_Model")

# compile the AE model
autoencoder.compile(optimizer='adam', loss='mse', metrics=['accuracy', 'mse'])
'''

# %%
input_encoder = Input(shape=(169,), name="encoder_input_layer")
# create the first encoder layer
#encoder_layer1 = Dense(units=85, name='encoder_layer1', activity_regularizer=regularizers.l1(10e-5))(input_encoder)
encoder_layer1 = Dense(units=43, name='encoder_layer1', )(input_encoder)

layer_1 = PReLU(alpha_initializer=Constant(value=0.3), name='enc_layer1_PReLU_Activation')(encoder_layer1)
#layer_1 = ELU()(encoder_layer1)

encoder_model = Model(inputs=input_encoder, outputs=layer_1, name='Encoder_Model')

# Create the Decoder model
input_decoder = Input(shape=(43,), name="Decoder_input_layer")
# decoder 2nd decoder layer
decoder_layer1 = Dense(units=169, name='decoder_layer1')(layer_1)
layer_2 = PReLU(alpha_initializer=Constant(value=0.3), name='dec_layer1_PReLU_Activation')(decoder_layer1)
#layer_2 = ELU()(decoder_layer1)

#decoder = Model(inputs=input_decoder, outputs=decoder_layer1)

# create the AE model
autoencoder = Model(inputs=input_encoder, outputs=layer_2, name="AutoEncoder_Model")

# compile the AE model
autoencoder.compile(optimizer='adam', loss='mse', metrics=['accuracy', 'mse'])

# %%
autoencoder.summary()

# %%
#plot_model(model=autoencoder, to_file='drive/My Drive/Thesis/data/Embedding_Data/ae_model_image.png', show_shapes=True, dpi=300)

# %%
early_stop = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=3)

# %%
autoencoder.fit(XTrain_embed, XTrain_embed, batch_size=128, epochs=100, validation_data=(XTest_embed, XTest_embed), workers=-1, callbacks=[early_stop])

# %%
losses = pd.DataFrame(autoencoder.history.history)
losses = losses[['loss', 'accuracy', 'val_loss', 'val_accuracy']]
losses.tail(4)

# %%
# plot the losses loss metrics
losses[['loss', 'val_loss']].plot(figsize=(15,7))
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.title('Training and Validation Loss - PReLU')
plt.grid()
plt.legend()

# %%
# plot the accuracy metrics
losses[['accuracy', 'val_accuracy']].plot(figsize=(15,7))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy - PReLu')
plt.legend()
plt.grid()

# %%
# also save the encoder model
# encoder_model.save("drive/My Drive/Thesis/data/Embedding_Data/embedding_encoder_22.h5")
# load the encoder model
encoder_model = load_model("drive/My Drive/Thesis/data/Embedding_Data/embedding_encoder_43.h5")

# %%
# Fetch the embeddings from the Encoder Model
encoder_embed_train = encoder_model.predict(XTrain_embed)
encoder_embed_test = encoder_model.predict(XTest_embed)

# %%
# remove old logs
# !rm -rf ./logs/

# %% [markdown]
# ## Testing Embeddings
# Here we test our embeddings

# %% [markdown]
# ### Random Forest RUL Evaluation

# %%
# Split embedding data based on Chassis information
train_dd, test_dd = validationSplit(data2, split=0.2)
# extract train and test data
#XTrain_embed = train_embed.iloc[:, :169].values
#XTest_embed = test_embed.iloc[:, :169].values

# %%
yTrain_dd = train_dd['RUL'].values
yTest_dd = test_dd['RUL'].values

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor(random_state=42, n_jobs=-1, n_estimators=100, criterion='mae', max_depth=100, verbose=2)

# %%
regr.fit(encoder_embed_train, yTrain_dd)

# %%
predictions = regr.predict(encoder_embed_test)

# %%
# plotting our prediction result
test_predictions = pd.Series(predictions.reshape(3823,))
pred_df = pd.DataFrame(yTest_dd, columns=['True RUL'])
pred_df = pd.concat([pred_df, test_predictions], axis=1)
pred_df.columns = ['True RUL', 'Predicted RUL']

# %%
plt.figure()
pred_df[:1000].plot(figsize=(20,10))
plt.xlabel('Data Samples')
plt.ylabel('RUL')
plt.title('Random Forest Prediction on AE Embeddings')

# %%
from sklearn.metrics import mean_absolute_error, explained_variance_score

# %%
# mean absolute error for our predictions
mean_absolute_error(pred_df['True RUL'], pred_df['Predicted RUL'])

# %%
# explained variance score
explained_variance_score(pred_df['True RUL'].values, pred_df['Predicted RUL'].values)

# %% [markdown]
# # View Embeddings

# %%
# import TSNE and PCA
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
tsne = TSNE(n_components=2, n_iter=1000, perplexity=50)
reduced_tsne = tsne.fit_transform(encoder_embed_test)

pca = PCA(n_components=2)
pca_data = pca.fit_transform(encoder_embed_test)

# %%
# label encoding for the chassis
chassis_target = pd.factorize(test_embed.loc[:, 'T_CHASSIS'].values)[0]
chassis_target.shape

# %%
codes, uniques = pd.factorize(test_embed.loc[:, 'T_CHASSIS'].values)

# %%
x1 = encoder_embed_test[1013]
x2 = encoder_embed_test[3000]


# calculating the cosing similarity of two vectors in the orginal space
a_dot = np.dot(x1, x2)
similar = a_dot / (np.linalg.norm(x1) * np.linalg.norm(x2))
similar

# %%
'''
0-746402 and O-678360, 0-778558
Chekc distance from 
O-803915 and O-719898
O-719156 and O-753014
'''

# %% [markdown]
# Observation between 0-746402 and O-678360. Calculating the cosine similarity between those two embedding points shows a value of 0.75161475. The farthest point to this is O-803915 and the similarity value is 0.25650138

# %% [markdown]
# 0.7942, 0.6742973 (ElU), 0.4070125 (PReLU)

# %%
x1 = XTest_embed[956]
x2 = XTest_embed[805]
#O-719898

# calculating the cosing similarity of two vectors in the orginal space
a_dot = np.dot(x1, x2)
similar = a_dot / (np.linalg.norm(x1) * np.linalg.norm(x2))
similar

# %%
np.unique(chassis_target[900:1000])

# %%
fig = plt.figure(figsize=(15,10))
scatter = plt.scatter(reduced_tsne[900:1000,0], reduced_tsne[900:1000,1], c=chassis_target[900:1000], marker='.', label=np.unique(chassis_target[900:1000]))
plt.title('Chassis - TSNE Embeddings Reduction')
plt.legend(handles=scatter.legend_elements()[0], labels=list(np.unique(chassis_target[900:1000])))

# %%
fig = plt.figure(figsize=(15,10))
scatter = plt.scatter(pca_data[900:1000,0], pca_data[900:1000,1], c=chassis_target[900:1000], marker='.', label=np.unique(chassis_target[900:1000]))
plt.title('Chassis - PCA Embeddings Reduction')
plt.legend(handles=scatter.legend_elements()[0], labels=list(np.unique(chassis_target[900:1000])))

# %%
## 
'''
0-746402 and O-678360, 0-778558
Chekc distance from 
O-803915 and O-719898
O-719156 and O-753014
'''
## '''

# %%
np.unique(chassis_target[:1000])

# %%
fig = plt.figure(figsize=(20, 10))
scatter2 = plt.scatter(reduced_tsne[:1000,0], reduced_tsne[:1000,1], c=chassis_target[:1000], cmap=plt.cm.get_cmap("gist_ncar"), marker='.')
plt.title('Chassis - TSNE Embeddings ')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')

counter = []
for i, txt in enumerate(test_embed.loc[:1000, 'T_CHASSIS'].values):
  if txt not in counter:
    plt.annotate(txt, (reduced_tsne[i,0], reduced_tsne[i,1]))
    counter.append(txt)

# %%
fig = plt.figure(figsize=(20,10))
plt.scatter(pca_data[:1000,0], pca_data[:1000,1], c=chassis_target[:1000], marker='.')
plt.title('Chassis - PCA Embeddings Reduction')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
counter = []
for i, txt in enumerate(test_embed.loc[:1000, 'T_CHASSIS'].values):
  if txt not in counter:
    plt.annotate(txt, (pca_data[i,0], pca_data[i,1]))
    counter.append(txt)

# %%
'''
Chekc distance from 
O-803915 and O-719898
O-719156 and O-753014
'''
