# %% [markdown]
# # Learned Embeddings
# This program will attempt to create embeddings for the categorical features.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import copy as copy

# %%
# using the latest updated file
data = pd.read_csv("drive/My Drive/Thesis/data/Data_Engineering/Edited_Raw_Data/v3_feature_engineering_data.csv", sep=',', low_memory=False)
#data = pd.read_csv("drive/My Drive/Thesis/data/Feature_Engineering/KNN_Imputed_Datasets/KNN_Imputed_k_40.csv", sep=',', low_memory=False)

#data = pd.read_csv("drive/My Drive/Thesis/data/Data_Engineering/Edited_Raw_Data/v2_Sorted_Database.csv", sep=',', low_memory=False)

# %%
data.shape
# Out:
# (19954, 435)

# %%
# the BIWEEK_SEND_DATE is a datetime feature and not just normal object date
data['BIWEEK_SEND_DATE'] = pd.to_datetime(data['BIWEEK_SEND_DATE'])
data['DELIVERY_DATE'] = pd.to_datetime(data['DELIVERY_DATE'])
data['LAST_RUN'] = pd.to_datetime(data['LAST_RUN'])
data['DELIVERY_DATE.1'] = pd.to_datetime(data['DELIVERY_DATE.1'])
data['LAST_RUN.1'] = pd.to_datetime(data['LAST_RUN.1'])

# %% [markdown]
# # Categorical Features
# We have 70 categorical features inlcuding the Chassis feature.
#
# The quesion pondering my mind is? Should the chassis feature be discared or used?

# %%
# find all categorical features.
data_cat = data.select_dtypes(include='object')
data_cat
# Out:
#        T_CHASSIS  ... VFE_0007_CAB_HEIGHT
# 0       O-774932  ...             CABH215
# 1       O-774932  ...             CABH215
# 2       O-774932  ...             CABH215
# 3       O-774932  ...             CABH215
# 4       O-774932  ...             CABH215
# ...          ...  ...                 ...
# 336672  O-781715  ...             CABH230
# 336673  O-781715  ...             CABH230
# 336674  O-781715  ...             CABH230
# 336675  O-781715  ...             CABH230
# 336676  O-781715  ...             CABH230
#
# [336677 rows x 71 columns]

# %% [markdown]
# ### No missing values in the categorical data

# %%
# check if we have any missing values in the categorical data
data_cat.isnull().sum().sum()
# Out:
# 0

# %%
# it seems some categorical features have the same values i.e std of 0
data_cat['VAR_2RB_BATTERY_MAINTENANCE'].unique()
# Out:
# array(['UBAMAFRE', 'BAMAFREE'], dtype=object)

# %%
## find categorical features with zero variance - Will don't need those features.
data_cat.columns
var_1_categories = []
for col in data_cat.columns:
  unique_Values = data_cat.loc[:, col].nunique()
  print (col, unique_Values)
  if unique_Values == 1:
    var_1_categories.append(col)
# Out:
# T_CHASSIS 6675
# COUNTRY_OF_OPERATION 1
# VAR_7MA_FRONT_AXLE_TYPE 2
# VAR_DPX_ENGINE_TYPE 3
# VAR_T1X_PTO_ENGINE_MOUNTED_REAR 2
# VAR_4DX_FRONT_BUMPER 3
# VAR_F1X_REAR_AXLE_LOAD 15
# VAR_FTX_GROUND_CLEARANCE_FA 5
# VAR_CKX_VEHICLE_PROFILE 2
# VAR_KTX_ENGINE_EMISSION_CONTROL 2
# VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP 5
# VAR_QCX_TOPOGRAPHY 3
# VAR_YLX_REAR_SUSPENSION_SYSTEM 2
# VAR_DKX_GROSS_COMBINATION_WEIGHT 11
# VAR_2RB_BATTERY_MAINTENANCE 2
# VAR_FAX_STEERING_WHEEL_POS 2
# VAR_2CX_CAB_VERSION 5
# VAR_2DX_REAR_CAB_SUSPENSION 2
# VAR_GSX_CHASSIS_HEIGHT 6
# VAR_FFX_PUSHER_AXLE_FEATURES 3
# VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE 3
# VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR 2
# VAR_5NX_ENGINE_BLOCK_HEATER 2
# VAR_TAX_REAR_AXLE_RATIO 24
# VAR_A3A_IDLE_SHUTDOWN 2
# VAR_2LX_FRONT_CAB_SUSPENSION 2
# VAR_RUX_GEAR_SHIFTING_SYSTEM 3
# VAR_U3X_BRAKE_FRONT 3
# VAR_T4X_PTO_TRANSM_MOUNTED 2
# VAR_UBX_HYDRAULIC_PUMP_ENG_MTD 2
# VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS 3
# VAR_REX_CRANK_CASE_VENTILATION 3
# VAR_78X_TRANSPORT_CYCLE 3
# VAR_T2X_TRANSMISSIONRETARDER_COOLER 2
# VAR_U4X_BRAKE_DRIVE_REAR 3
# VAR_FVX_FRONT_AXLE_LOAD 8
# VAR_VWX_COMPRESSOR_CAPACITY 3
# VAR_DAX_AXLE_ARRANGEMENT 6
# VAR_H1B_TURBO_APPLICATION 2
# VAR_FDX_REAR_AXLE_ARRANGEMENT 7
# VAR_7PX_HYDRAULIC_PUMP_GEARBOX_MOUNTED 2
# VAR_7NA_FRONT_SUSPENSION_INSTALLATION 4
# VAR_LKX_DRIVER_STATE_SENSING_SYSTEM 2
# VAR_QWX_TURBO 2
# VAR_FZX_FRONT_AXLE_ARRANGEMENT 2
# VAR_V6X_RETARDER 2
# VAR_K4C_VEHICLE_UPTIME_SETTINGS 3
# VAR_0RA_REGENERATION_CONTROLS_DPF 4
# VAR_YKX_FRONT_SUSPENSION_SYSTEM 2
# VAR_T3X_PTO_ENGINE_REAR_MOUNTED 2
# VAR_PJX_ALTERNATOR_CAPACITY 3
# VAR_41X_PARKING_HEATER 4
# VAR_D7C_WHOLE_VEHICLE_TYPE_APPROVAL 2
# VAR_5JB_TELEMATICS_COMMUNICAT_GATEWAYS 2
# VAR_RWX_TRANSMISSION 8
# VAR_DHX_ROAD_CONDITION 2
# VAR_2EX_CAB_TILT_PUMP 2
# VAR_D9C_EMISSION_LEVEL 4
# VAR_DDX_CHASSIS_TYPE 2
# VAR_O8A_ENGINE_PTO_TORQUE_CAPACITY 3
# VAR_33A_CAB_HEIGHT 7
# VAR_J2A_ACTIVE_STEERING 2
# VAR_N9C_ADR_CLASSIFICATION 4
# VFE_0001_HORSE_POWER 3
# VFE_0002_GROSS_COMBINATION_WEIGHT_BIN 3
# VFE_0003_ENGINE_GENERATION 3
# VFE_0004_REAR_AXLE_LOAD_BIN 11
# VFE_0005_REAR_AXLE_RATIO_BIN 16
# VFE_0009_LTVF_TYPE 6
# VFE_0006_VEHICLE_OPERATION_DIGIT2 9
# VFE_0007_CAB_HEIGHT 7

# %%
# Categorical Variables with only 1 value. i.e std is 0
var_1_categories
# Out:
# ['COUNTRY_OF_OPERATION']

# %% [markdown]
# ## Embeddings

# %% [markdown]
# In order to apply embeddings for out categorical variables. We need to first determine which features are categorical variable and which are not. We need to ensure we caputure all possible cases of the categorical features.
#
# Okay, then for each categorical variable we need to capture the cardinalty of the feature iteself.

# %%
# we are going to discard the T_CHASSIS feature
categorical_features = data_cat.columns[1:]
categorical_features
# Out:
# Index(['COUNTRY_OF_OPERATION', 'VAR_7MA_FRONT_AXLE_TYPE',
#        'VAR_DPX_ENGINE_TYPE', 'VAR_T1X_PTO_ENGINE_MOUNTED_REAR',
#        'VAR_4DX_FRONT_BUMPER', 'VAR_F1X_REAR_AXLE_LOAD',
#        'VAR_FTX_GROUND_CLEARANCE_FA', 'VAR_CKX_VEHICLE_PROFILE',
#        'VAR_KTX_ENGINE_EMISSION_CONTROL',
#        'VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP', 'VAR_QCX_TOPOGRAPHY',
#        'VAR_YLX_REAR_SUSPENSION_SYSTEM', 'VAR_DKX_GROSS_COMBINATION_WEIGHT',
#        'VAR_2RB_BATTERY_MAINTENANCE', 'VAR_FAX_STEERING_WHEEL_POS',
#        'VAR_2CX_CAB_VERSION', 'VAR_2DX_REAR_CAB_SUSPENSION',
#        'VAR_GSX_CHASSIS_HEIGHT', 'VAR_FFX_PUSHER_AXLE_FEATURES',
#        'VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE',
#        'VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR', 'VAR_5NX_ENGINE_BLOCK_HEATER',
#        'VAR_TAX_REAR_AXLE_RATIO', 'VAR_A3A_IDLE_SHUTDOWN',
#        'VAR_2LX_FRONT_CAB_SUSPENSION', 'VAR_RUX_GEAR_SHIFTING_SYSTEM',
#        'VAR_U3X_BRAKE_FRONT', 'VAR_T4X_PTO_TRANSM_MOUNTED',
#        'VAR_UBX_HYDRAULIC_PUMP_ENG_MTD',
#        'VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS',
#        'VAR_REX_CRANK_CASE_VENTILATION', 'VAR_78X_TRANSPORT_CYCLE',
#        'VAR_T2X_TRANSMISSIONRETARDER_COOLER', 'VAR_U4X_BRAKE_DRIVE_REAR',
#        'VAR_FVX_FRONT_AXLE_LOAD', 'VAR_VWX_COMPRESSOR_CAPACITY',
#        'VAR_DAX_AXLE_ARRANGEMENT', 'VAR_H1B_TURBO_APPLICATION',
#        'VAR_FDX_REAR_AXLE_ARRANGEMENT',
#        'VAR_7PX_HYDRAULIC_PUMP_GEARBOX_MOUNTED',
#        'VAR_7NA_FRONT_SUSPENSION_INSTALLATION',
#        'VAR_LKX_DRIVER_STATE_SENSING_SYSTEM', 'VAR_QWX_TURBO',
#        'VAR_FZX_FRONT_AXLE_ARRANGEMENT', 'VAR_V6X_RETARDER',
#        'VAR_K4C_VEHICLE_UPTIME_SETTINGS', 'VAR_0RA_REGENERATION_CONTROLS_DPF',
#        'VAR_YKX_FRONT_SUSPENSION_SYSTEM', 'VAR_T3X_PTO_ENGINE_REAR_MOUNTED',
#        'VAR_PJX_ALTERNATOR_CAPACITY', 'VAR_41X_PARKING_HEATER',
#        'VAR_D7C_WHOLE_VEHICLE_TYPE_APPROVAL',
#        'VAR_5JB_TELEMATICS_COMMUNICAT_GATEWAYS', 'VAR_RWX_TRANSMISSION',
#        'VAR_DHX_ROAD_CONDITION', 'VAR_2EX_CAB_TILT_PUMP',
#        'VAR_D9C_EMISSION_LEVEL', 'VAR_DDX_CHASSIS_TYPE',
#        'VAR_O8A_ENGINE_PTO_TORQUE_CAPACITY', 'VAR_33A_CAB_HEIGHT',
#        'VAR_J2A_ACTIVE_STEERING', 'VAR_N9C_ADR_CLASSIFICATION',
#        'VFE_0001_HORSE_POWER', 'VFE_0002_GROSS_COMBINATION_WEIGHT_BIN',
#        'VFE_0003_ENGINE_GENERATION', 'VFE_0004_REAR_AXLE_LOAD_BIN',
#        'VFE_0005_REAR_AXLE_RATIO_BIN', 'VFE_0009_LTVF_TYPE',
#        'VFE_0006_VEHICLE_OPERATION_DIGIT2', 'VFE_0007_CAB_HEIGHT'],
#       dtype='object')

# %%
# fetch cardinality of out categorical variables.
cat_cardinality = [(cols, data_cat[cols].nunique()) for cols in categorical_features]
cat_cardinality
# Out:
# [('COUNTRY_OF_OPERATION', 1),
#  ('VAR_7MA_FRONT_AXLE_TYPE', 2),
#  ('VAR_DPX_ENGINE_TYPE', 3),
#  ('VAR_T1X_PTO_ENGINE_MOUNTED_REAR', 2),
#  ('VAR_4DX_FRONT_BUMPER', 3),
#  ('VAR_F1X_REAR_AXLE_LOAD', 15),
#  ('VAR_FTX_GROUND_CLEARANCE_FA', 5),
#  ('VAR_CKX_VEHICLE_PROFILE', 2),
#  ('VAR_KTX_ENGINE_EMISSION_CONTROL', 2),
#  ('VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP', 5),
#  ('VAR_QCX_TOPOGRAPHY', 3),
#  ('VAR_YLX_REAR_SUSPENSION_SYSTEM', 2),
#  ('VAR_DKX_GROSS_COMBINATION_WEIGHT', 11),
#  ('VAR_2RB_BATTERY_MAINTENANCE', 2),
#  ('VAR_FAX_STEERING_WHEEL_POS', 2),
#  ('VAR_2CX_CAB_VERSION', 5),
#  ('VAR_2DX_REAR_CAB_SUSPENSION', 2),
#  ('VAR_GSX_CHASSIS_HEIGHT', 6),
#  ('VAR_FFX_PUSHER_AXLE_FEATURES', 3),
#  ('VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE', 3),
#  ('VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR', 2),
#  ('VAR_5NX_ENGINE_BLOCK_HEATER', 2),
#  ('VAR_TAX_REAR_AXLE_RATIO', 24),
#  ('VAR_A3A_IDLE_SHUTDOWN', 2),
#  ('VAR_2LX_FRONT_CAB_SUSPENSION', 2),
#  ('VAR_RUX_GEAR_SHIFTING_SYSTEM', 3),
#  ('VAR_U3X_BRAKE_FRONT', 3),
#  ('VAR_T4X_PTO_TRANSM_MOUNTED', 2),
#  ('VAR_UBX_HYDRAULIC_PUMP_ENG_MTD', 2),
#  ('VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS', 3),
#  ('VAR_REX_CRANK_CASE_VENTILATION', 3),
#  ('VAR_78X_TRANSPORT_CYCLE', 3),
#  ('VAR_T2X_TRANSMISSIONRETARDER_COOLER', 2),
#  ('VAR_U4X_BRAKE_DRIVE_REAR', 3),
#  ('VAR_FVX_FRONT_AXLE_LOAD', 8),
#  ('VAR_VWX_COMPRESSOR_CAPACITY', 3),
#  ('VAR_DAX_AXLE_ARRANGEMENT', 6),
#  ('VAR_H1B_TURBO_APPLICATION', 2),
#  ('VAR_FDX_REAR_AXLE_ARRANGEMENT', 7),
#  ('VAR_7PX_HYDRAULIC_PUMP_GEARBOX_MOUNTED', 2),
#  ('VAR_7NA_FRONT_SUSPENSION_INSTALLATION', 4),
#  ('VAR_LKX_DRIVER_STATE_SENSING_SYSTEM', 2),
#  ('VAR_QWX_TURBO', 2),
#  ('VAR_FZX_FRONT_AXLE_ARRANGEMENT', 2),
#  ('VAR_V6X_RETARDER', 2),
#  ('VAR_K4C_VEHICLE_UPTIME_SETTINGS', 3),
#  ('VAR_0RA_REGENERATION_CONTROLS_DPF', 4),
#  ('VAR_YKX_FRONT_SUSPENSION_SYSTEM', 2),
#  ('VAR_T3X_PTO_ENGINE_REAR_MOUNTED', 2),
#  ('VAR_PJX_ALTERNATOR_CAPACITY', 3),
#  ('VAR_41X_PARKING_HEATER', 4),
#  ('VAR_D7C_WHOLE_VEHICLE_TYPE_APPROVAL', 2),
#  ('VAR_5JB_TELEMATICS_COMMUNICAT_GATEWAYS', 2),
#  ('VAR_RWX_TRANSMISSION', 8),
#  ('VAR_DHX_ROAD_CONDITION', 2),
#  ('VAR_2EX_CAB_TILT_PUMP', 2),
#  ('VAR_D9C_EMISSION_LEVEL', 4),
#  ('VAR_DDX_CHASSIS_TYPE', 2),
#  ('VAR_O8A_ENGINE_PTO_TORQUE_CAPACITY', 3),
#  ('VAR_33A_CAB_HEIGHT', 7),
#  ('VAR_J2A_ACTIVE_STEERING', 2),
#  ('VAR_N9C_ADR_CLASSIFICATION', 4),
#  ('VFE_0001_HORSE_POWER', 3),
#  ('VFE_0002_GROSS_COMBINATION_WEIGHT_BIN', 3),
#  ('VFE_0003_ENGINE_GENERATION', 3),
#  ('VFE_0004_REAR_AXLE_LOAD_BIN', 11),
#  ('VFE_0005_REAR_AXLE_RATIO_BIN', 16),
#  ('VFE_0009_LTVF_TYPE', 6),
#  ('VFE_0006_VEHICLE_OPERATION_DIGIT2', 9),
#  ('VFE_0007_CAB_HEIGHT', 7)]

# %%
# check out which feature has the maximum cardinality
#max_cardinality = max(np.array(cat_cardinality)[:,1])
max_cad_feature = np.argmax(np.array(cat_cardinality)[:,1].astype(int))
max_cardinality = cat_cardinality[max_cad_feature]
max_cardinality
# Out:
# ('VAR_TAX_REAR_AXLE_RATIO', 24)

# %%
# I use the cardinality of each variable to decide how large its embedding matrix should be.
# max size of 10
embedding_size = np.array([(col_names, c, min(10, (c+1)//2)) for col_names,c in cat_cardinality])
embedding_size.shape
# Out:
# (70, 3)

# %%
# create a dataframe of the features and their sizes
cat_features_df = pd.DataFrame(data=embedding_size, columns=['Feature', 'Cardinality', 'Embedding_Size'])
# transform the dtypes
cat_features_df = cat_features_df.astype({'Cardinality': 'int32', 'Embedding_Size': 'int32'}, copy=False)
cat_features_df
# Out:
#                               Feature  Cardinality  Embedding_Size
# 0                COUNTRY_OF_OPERATION            1               1
# 1             VAR_7MA_FRONT_AXLE_TYPE            2               1
# 2                 VAR_DPX_ENGINE_TYPE            3               2
# 3     VAR_T1X_PTO_ENGINE_MOUNTED_REAR            2               1
# 4                VAR_4DX_FRONT_BUMPER            3               2
# ..                                ...          ...             ...
# 65        VFE_0004_REAR_AXLE_LOAD_BIN           11               6
# 66       VFE_0005_REAR_AXLE_RATIO_BIN           16               8
# 67                 VFE_0009_LTVF_TYPE            6               3
# 68  VFE_0006_VEHICLE_OPERATION_DIGIT2            9               5
# 69                VFE_0007_CAB_HEIGHT            7               4
#
# [70 rows x 3 columns]

# %%
for feature in cat_features_df:
  print (feature)
# Out:
# Feature
# Cardinality
# Embedding_Size

# %%
# use tensorflow version 2
# %tensorflow_version 2.x

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, Input, Reshape, Concatenate, Dense, Flatten

from tensorflow.keras.callbacks import TensorBoard
import os
import datetime

from tensorflow.keras.utils import plot_model

# %%
from keras.layers import merge

# %% [markdown]
# ### Creating the Keras Embeddings

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

# %%
### Creating the Keras Embeddings

# IDs representing 1-hot encodings
# Need to create the input for all features
cat_embedding_input_layers = []

cat_reshape_layers = []
# Embeddings for the first cat feature
id_feature = 0
# create an array of embeddings layers
cat_embedding_layers = []

#model.add(Reshape(target_shape=(embedding_size,)))

# interate through categorical varaibles
for id_feature in range(cat_features_df.shape[0]):
  # creating the input layer for the embeddings
  input_layer = Input(shape=(1,), name="Input_layer_"+cat_features_df.loc[id_feature, 'Feature'])
  cat_embedding_input_layers.append(input_layer)
  # embedding size 
  layer_embedding_size = cat_features_df.loc[id_feature, 'Embedding_Size']
  # create the embedding layers
  embedded_layer = Embedding(input_dim=cat_features_df.loc[id_feature, 'Cardinality'], output_dim=layer_embedding_size, name="Embedding_layer_"+cat_features_df.loc[id_feature, 'Feature'], input_length = 1)(input_layer)
  cat_embedding_layers.append(embedded_layer)
  # add a reshape of the embedding layers
  reshape_layer = Reshape(target_shape=(layer_embedding_size,))(embedded_layer)
  # appends the rehshape models together
  cat_reshape_layers.append(reshape_layer)

# %%
'''
# Reshape and merge all embeddings together
reshape = Reshape(target_shape=(10,))
combined = Concatenate([reshape(prior), reshape(store), reshape(shopper)])
'''
# Out:
# '\n# Reshape and merge all embeddings together\nreshape = Reshape(target_shape=(10,))\ncombined = Concatenate([reshape(prior), reshape(store), reshape(shopper)])\n'

# %%
# create a merge layer for all embedding layer
combined_layer = Concatenate(axis=1)(cat_reshape_layers)

dense_layer_1 = Dense(units=128, activation='relu', name='1st_Dense_Layer')(combined_layer)

# %%
### creating the embedding model
model_emb = Model(inputs=cat_embedding_input_layers, outputs=dense_layer_1, name="Categorical_Embeddings")

# compile the model
model_emb.compile(optimizer='rmsprop', loss='mse')

# %%
# plot the model
plot_model(model=model_emb, to_file='model_emp.png', show_shapes=True, dpi=300)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.193242 to fit

# %%
model_emb.summary()
# Out:
# Model: "Categorical_Embeddings"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input_layer_COUNTRY_OF_OPERATIO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_7MA_FRONT_AXLE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_DPX_ENGINE_TYPE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_T1X_PTO_ENGINE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_4DX_FRONT_BUMPE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_F1X_REAR_AXLE_L [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_FTX_GROUND_CLEA [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_CKX_VEHICLE_PRO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_KTX_ENGINE_EMIS [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_3ZB_TRANSMISSIO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_QCX_TOPOGRAPHY  [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_YLX_REAR_SUSPEN [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_DKX_GROSS_COMBI [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_2RB_BATTERY_MAI [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_FAX_STEERING_WH [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_2CX_CAB_VERSION [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_2DX_REAR_CAB_SU [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_GSX_CHASSIS_HEI [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_FFX_PUSHER_AXLE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_5CB_AIR_SUSP_FE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_2GB_CLUTCHABLE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_5NX_ENGINE_BLOC [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_TAX_REAR_AXLE_R [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_A3A_IDLE_SHUTDO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_2LX_FRONT_CAB_S [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_RUX_GEAR_SHIFTI [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_U3X_BRAKE_FRONT [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_T4X_PTO_TRANSM_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_UBX_HYDRAULIC_P [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_4QB_BODYBUILDER [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_REX_CRANK_CASE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_78X_TRANSPORT_C [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_T2X_TRANSMISSIO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_U4X_BRAKE_DRIVE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_FVX_FRONT_AXLE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_VWX_COMPRESSOR_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_DAX_AXLE_ARRANG [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_H1B_TURBO_APPLI [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_FDX_REAR_AXLE_A [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_7PX_HYDRAULIC_P [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_7NA_FRONT_SUSPE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_LKX_DRIVER_STAT [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_QWX_TURBO (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_FZX_FRONT_AXLE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_V6X_RETARDER (I [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_K4C_VEHICLE_UPT [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_0RA_REGENERATIO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_YKX_FRONT_SUSPE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_T3X_PTO_ENGINE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_PJX_ALTERNATOR_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_41X_PARKING_HEA [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_D7C_WHOLE_VEHIC [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_5JB_TELEMATICS_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_RWX_TRANSMISSIO [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_DHX_ROAD_CONDIT [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_2EX_CAB_TILT_PU [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_D9C_EMISSION_LE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_DDX_CHASSIS_TYP [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_O8A_ENGINE_PTO_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_33A_CAB_HEIGHT  [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_J2A_ACTIVE_STEE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VAR_N9C_ADR_CLASSIF [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0001_HORSE_POWE [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0002_GROSS_COMB [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0003_ENGINE_GEN [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0004_REAR_AXLE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0005_REAR_AXLE_ [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0009_LTVF_TYPE  [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0006_VEHICLE_OP [(None, 1)]          0
# __________________________________________________________________________________________________
# Input_layer_VFE_0007_CAB_HEIGHT [(None, 1)]          0
# __________________________________________________________________________________________________
# Embedding_layer_COUNTRY_OF_OPER (None, 1, 1)         1           Input_layer_COUNTRY_OF_OPERATION[
# __________________________________________________________________________________________________
# Embedding_layer_VAR_7MA_FRONT_A (None, 1, 1)         2           Input_layer_VAR_7MA_FRONT_AXLE_TY
# __________________________________________________________________________________________________
# Embedding_layer_VAR_DPX_ENGINE_ (None, 1, 2)         6           Input_layer_VAR_DPX_ENGINE_TYPE[0
# __________________________________________________________________________________________________
# Embedding_layer_VAR_T1X_PTO_ENG (None, 1, 1)         2           Input_layer_VAR_T1X_PTO_ENGINE_MO
# __________________________________________________________________________________________________
# Embedding_layer_VAR_4DX_FRONT_B (None, 1, 2)         6           Input_layer_VAR_4DX_FRONT_BUMPER[
# __________________________________________________________________________________________________
# Embedding_layer_VAR_F1X_REAR_AX (None, 1, 8)         120         Input_layer_VAR_F1X_REAR_AXLE_LOA
# __________________________________________________________________________________________________
# Embedding_layer_VAR_FTX_GROUND_ (None, 1, 3)         15          Input_layer_VAR_FTX_GROUND_CLEARA
# __________________________________________________________________________________________________
# Embedding_layer_VAR_CKX_VEHICLE (None, 1, 1)         2           Input_layer_VAR_CKX_VEHICLE_PROFI
# __________________________________________________________________________________________________
# Embedding_layer_VAR_KTX_ENGINE_ (None, 1, 1)         2           Input_layer_VAR_KTX_ENGINE_EMISSI
# __________________________________________________________________________________________________
# Embedding_layer_VAR_3ZB_TRANSMI (None, 1, 3)         15          Input_layer_VAR_3ZB_TRANSMISSION_
# __________________________________________________________________________________________________
# Embedding_layer_VAR_QCX_TOPOGRA (None, 1, 2)         6           Input_layer_VAR_QCX_TOPOGRAPHY[0]
# __________________________________________________________________________________________________
# Embedding_layer_VAR_YLX_REAR_SU (None, 1, 1)         2           Input_layer_VAR_YLX_REAR_SUSPENSI
# __________________________________________________________________________________________________
# Embedding_layer_VAR_DKX_GROSS_C (None, 1, 6)         66          Input_layer_VAR_DKX_GROSS_COMBINA
# __________________________________________________________________________________________________
# Embedding_layer_VAR_2RB_BATTERY (None, 1, 1)         2           Input_layer_VAR_2RB_BATTERY_MAINT
# __________________________________________________________________________________________________
# Embedding_layer_VAR_FAX_STEERIN (None, 1, 1)         2           Input_layer_VAR_FAX_STEERING_WHEE
# __________________________________________________________________________________________________
# Embedding_layer_VAR_2CX_CAB_VER (None, 1, 3)         15          Input_layer_VAR_2CX_CAB_VERSION[0
# __________________________________________________________________________________________________
# Embedding_layer_VAR_2DX_REAR_CA (None, 1, 1)         2           Input_layer_VAR_2DX_REAR_CAB_SUSP
# __________________________________________________________________________________________________
# Embedding_layer_VAR_GSX_CHASSIS (None, 1, 3)         18          Input_layer_VAR_GSX_CHASSIS_HEIGH
# __________________________________________________________________________________________________
# Embedding_layer_VAR_FFX_PUSHER_ (None, 1, 2)         6           Input_layer_VAR_FFX_PUSHER_AXLE_F
# __________________________________________________________________________________________________
# Embedding_layer_VAR_5CB_AIR_SUS (None, 1, 2)         6           Input_layer_VAR_5CB_AIR_SUSP_FEAT
# __________________________________________________________________________________________________
# Embedding_layer_VAR_2GB_CLUTCHA (None, 1, 1)         2           Input_layer_VAR_2GB_CLUTCHABLE_AI
# __________________________________________________________________________________________________
# Embedding_layer_VAR_5NX_ENGINE_ (None, 1, 1)         2           Input_layer_VAR_5NX_ENGINE_BLOCK_
# __________________________________________________________________________________________________
# Embedding_layer_VAR_TAX_REAR_AX (None, 1, 10)        240         Input_layer_VAR_TAX_REAR_AXLE_RAT
# __________________________________________________________________________________________________
# Embedding_layer_VAR_A3A_IDLE_SH (None, 1, 1)         2           Input_layer_VAR_A3A_IDLE_SHUTDOWN
# __________________________________________________________________________________________________
# Embedding_layer_VAR_2LX_FRONT_C (None, 1, 1)         2           Input_layer_VAR_2LX_FRONT_CAB_SUS
# __________________________________________________________________________________________________
# Embedding_layer_VAR_RUX_GEAR_SH (None, 1, 2)         6           Input_layer_VAR_RUX_GEAR_SHIFTING
# __________________________________________________________________________________________________
# Embedding_layer_VAR_U3X_BRAKE_F (None, 1, 2)         6           Input_layer_VAR_U3X_BRAKE_FRONT[0
# __________________________________________________________________________________________________
# Embedding_layer_VAR_T4X_PTO_TRA (None, 1, 1)         2           Input_layer_VAR_T4X_PTO_TRANSM_MO
# __________________________________________________________________________________________________
# Embedding_layer_VAR_UBX_HYDRAUL (None, 1, 1)         2           Input_layer_VAR_UBX_HYDRAULIC_PUM
# __________________________________________________________________________________________________
# Embedding_layer_VAR_4QB_BODYBUI (None, 1, 2)         6           Input_layer_VAR_4QB_BODYBUILDER_E
# __________________________________________________________________________________________________
# Embedding_layer_VAR_REX_CRANK_C (None, 1, 2)         6           Input_layer_VAR_REX_CRANK_CASE_VE
# __________________________________________________________________________________________________
# Embedding_layer_VAR_78X_TRANSPO (None, 1, 2)         6           Input_layer_VAR_78X_TRANSPORT_CYC
# __________________________________________________________________________________________________
# Embedding_layer_VAR_T2X_TRANSMI (None, 1, 1)         2           Input_layer_VAR_T2X_TRANSMISSIONR
# __________________________________________________________________________________________________
# Embedding_layer_VAR_U4X_BRAKE_D (None, 1, 2)         6           Input_layer_VAR_U4X_BRAKE_DRIVE_R
# __________________________________________________________________________________________________
# Embedding_layer_VAR_FVX_FRONT_A (None, 1, 4)         32          Input_layer_VAR_FVX_FRONT_AXLE_LO
# __________________________________________________________________________________________________
# Embedding_layer_VAR_VWX_COMPRES (None, 1, 2)         6           Input_layer_VAR_VWX_COMPRESSOR_CA
# __________________________________________________________________________________________________
# Embedding_layer_VAR_DAX_AXLE_AR (None, 1, 3)         18          Input_layer_VAR_DAX_AXLE_ARRANGEM
# __________________________________________________________________________________________________
# Embedding_layer_VAR_H1B_TURBO_A (None, 1, 1)         2           Input_layer_VAR_H1B_TURBO_APPLICA
# __________________________________________________________________________________________________
# Embedding_layer_VAR_FDX_REAR_AX (None, 1, 4)         28          Input_layer_VAR_FDX_REAR_AXLE_ARR
# __________________________________________________________________________________________________
# Embedding_layer_VAR_7PX_HYDRAUL (None, 1, 1)         2           Input_layer_VAR_7PX_HYDRAULIC_PUM
# __________________________________________________________________________________________________
# Embedding_layer_VAR_7NA_FRONT_S (None, 1, 2)         8           Input_layer_VAR_7NA_FRONT_SUSPENS
# __________________________________________________________________________________________________
# Embedding_layer_VAR_LKX_DRIVER_ (None, 1, 1)         2           Input_layer_VAR_LKX_DRIVER_STATE_
# __________________________________________________________________________________________________
# Embedding_layer_VAR_QWX_TURBO ( (None, 1, 1)         2           Input_layer_VAR_QWX_TURBO[0][0]
# __________________________________________________________________________________________________
# Embedding_layer_VAR_FZX_FRONT_A (None, 1, 1)         2           Input_layer_VAR_FZX_FRONT_AXLE_AR
# __________________________________________________________________________________________________
# Embedding_layer_VAR_V6X_RETARDE (None, 1, 1)         2           Input_layer_VAR_V6X_RETARDER[0][0
# __________________________________________________________________________________________________
# Embedding_layer_VAR_K4C_VEHICLE (None, 1, 2)         6           Input_layer_VAR_K4C_VEHICLE_UPTIM
# __________________________________________________________________________________________________
# Embedding_layer_VAR_0RA_REGENER (None, 1, 2)         8           Input_layer_VAR_0RA_REGENERATION_
# __________________________________________________________________________________________________
# Embedding_layer_VAR_YKX_FRONT_S (None, 1, 1)         2           Input_layer_VAR_YKX_FRONT_SUSPENS
# __________________________________________________________________________________________________
# Embedding_layer_VAR_T3X_PTO_ENG (None, 1, 1)         2           Input_layer_VAR_T3X_PTO_ENGINE_RE
# __________________________________________________________________________________________________
# Embedding_layer_VAR_PJX_ALTERNA (None, 1, 2)         6           Input_layer_VAR_PJX_ALTERNATOR_CA
# __________________________________________________________________________________________________
# Embedding_layer_VAR_41X_PARKING (None, 1, 2)         8           Input_layer_VAR_41X_PARKING_HEATE
# __________________________________________________________________________________________________
# Embedding_layer_VAR_D7C_WHOLE_V (None, 1, 1)         2           Input_layer_VAR_D7C_WHOLE_VEHICLE
# __________________________________________________________________________________________________
# Embedding_layer_VAR_5JB_TELEMAT (None, 1, 1)         2           Input_layer_VAR_5JB_TELEMATICS_CO
# __________________________________________________________________________________________________
# Embedding_layer_VAR_RWX_TRANSMI (None, 1, 4)         32          Input_layer_VAR_RWX_TRANSMISSION[
# __________________________________________________________________________________________________
# Embedding_layer_VAR_DHX_ROAD_CO (None, 1, 1)         2           Input_layer_VAR_DHX_ROAD_CONDITIO
# __________________________________________________________________________________________________
# Embedding_layer_VAR_2EX_CAB_TIL (None, 1, 1)         2           Input_layer_VAR_2EX_CAB_TILT_PUMP
# __________________________________________________________________________________________________
# Embedding_layer_VAR_D9C_EMISSIO (None, 1, 2)         8           Input_layer_VAR_D9C_EMISSION_LEVE
# __________________________________________________________________________________________________
# Embedding_layer_VAR_DDX_CHASSIS (None, 1, 1)         2           Input_layer_VAR_DDX_CHASSIS_TYPE[
# __________________________________________________________________________________________________
# Embedding_layer_VAR_O8A_ENGINE_ (None, 1, 2)         6           Input_layer_VAR_O8A_ENGINE_PTO_TO
# __________________________________________________________________________________________________
# Embedding_layer_VAR_33A_CAB_HEI (None, 1, 4)         28          Input_layer_VAR_33A_CAB_HEIGHT[0]
# __________________________________________________________________________________________________
# Embedding_layer_VAR_J2A_ACTIVE_ (None, 1, 1)         2           Input_layer_VAR_J2A_ACTIVE_STEERI
# __________________________________________________________________________________________________
# Embedding_layer_VAR_N9C_ADR_CLA (None, 1, 2)         8           Input_layer_VAR_N9C_ADR_CLASSIFIC
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0001_HORSE_ (None, 1, 2)         6           Input_layer_VFE_0001_HORSE_POWER[
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0002_GROSS_ (None, 1, 2)         6           Input_layer_VFE_0002_GROSS_COMBIN
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0003_ENGINE (None, 1, 2)         6           Input_layer_VFE_0003_ENGINE_GENER
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0004_REAR_A (None, 1, 6)         66          Input_layer_VFE_0004_REAR_AXLE_LO
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0005_REAR_A (None, 1, 8)         128         Input_layer_VFE_0005_REAR_AXLE_RA
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0009_LTVF_T (None, 1, 3)         18          Input_layer_VFE_0009_LTVF_TYPE[0]
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0006_VEHICL (None, 1, 5)         45          Input_layer_VFE_0006_VEHICLE_OPER
# __________________________________________________________________________________________________
# Embedding_layer_VFE_0007_CAB_HE (None, 1, 4)         28          Input_layer_VFE_0007_CAB_HEIGHT[0
# __________________________________________________________________________________________________
# reshape_143 (Reshape)           (None, 1)            0           Embedding_layer_COUNTRY_OF_OPERAT
# __________________________________________________________________________________________________
# reshape_144 (Reshape)           (None, 1)            0           Embedding_layer_VAR_7MA_FRONT_AXL
# __________________________________________________________________________________________________
# reshape_145 (Reshape)           (None, 2)            0           Embedding_layer_VAR_DPX_ENGINE_TY
# __________________________________________________________________________________________________
# reshape_146 (Reshape)           (None, 1)            0           Embedding_layer_VAR_T1X_PTO_ENGIN
# __________________________________________________________________________________________________
# reshape_147 (Reshape)           (None, 2)            0           Embedding_layer_VAR_4DX_FRONT_BUM
# __________________________________________________________________________________________________
# reshape_148 (Reshape)           (None, 8)            0           Embedding_layer_VAR_F1X_REAR_AXLE
# __________________________________________________________________________________________________
# reshape_149 (Reshape)           (None, 3)            0           Embedding_layer_VAR_FTX_GROUND_CL
# __________________________________________________________________________________________________
# reshape_150 (Reshape)           (None, 1)            0           Embedding_layer_VAR_CKX_VEHICLE_P
# __________________________________________________________________________________________________
# reshape_151 (Reshape)           (None, 1)            0           Embedding_layer_VAR_KTX_ENGINE_EM
# __________________________________________________________________________________________________
# reshape_152 (Reshape)           (None, 3)            0           Embedding_layer_VAR_3ZB_TRANSMISS
# __________________________________________________________________________________________________
# reshape_153 (Reshape)           (None, 2)            0           Embedding_layer_VAR_QCX_TOPOGRAPH
# __________________________________________________________________________________________________
# reshape_154 (Reshape)           (None, 1)            0           Embedding_layer_VAR_YLX_REAR_SUSP
# __________________________________________________________________________________________________
# reshape_155 (Reshape)           (None, 6)            0           Embedding_layer_VAR_DKX_GROSS_COM
# __________________________________________________________________________________________________
# reshape_156 (Reshape)           (None, 1)            0           Embedding_layer_VAR_2RB_BATTERY_M
# __________________________________________________________________________________________________
# reshape_157 (Reshape)           (None, 1)            0           Embedding_layer_VAR_FAX_STEERING_
# __________________________________________________________________________________________________
# reshape_158 (Reshape)           (None, 3)            0           Embedding_layer_VAR_2CX_CAB_VERSI
# __________________________________________________________________________________________________
# reshape_159 (Reshape)           (None, 1)            0           Embedding_layer_VAR_2DX_REAR_CAB_
# __________________________________________________________________________________________________
# reshape_160 (Reshape)           (None, 3)            0           Embedding_layer_VAR_GSX_CHASSIS_H
# __________________________________________________________________________________________________
# reshape_161 (Reshape)           (None, 2)            0           Embedding_layer_VAR_FFX_PUSHER_AX
# __________________________________________________________________________________________________
# reshape_162 (Reshape)           (None, 2)            0           Embedding_layer_VAR_5CB_AIR_SUSP_
# __________________________________________________________________________________________________
# reshape_163 (Reshape)           (None, 1)            0           Embedding_layer_VAR_2GB_CLUTCHABL
# __________________________________________________________________________________________________
# reshape_164 (Reshape)           (None, 1)            0           Embedding_layer_VAR_5NX_ENGINE_BL
# __________________________________________________________________________________________________
# reshape_165 (Reshape)           (None, 10)           0           Embedding_layer_VAR_TAX_REAR_AXLE
# __________________________________________________________________________________________________
# reshape_166 (Reshape)           (None, 1)            0           Embedding_layer_VAR_A3A_IDLE_SHUT
# __________________________________________________________________________________________________
# reshape_167 (Reshape)           (None, 1)            0           Embedding_layer_VAR_2LX_FRONT_CAB
# __________________________________________________________________________________________________
# reshape_168 (Reshape)           (None, 2)            0           Embedding_layer_VAR_RUX_GEAR_SHIF
# __________________________________________________________________________________________________
# reshape_169 (Reshape)           (None, 2)            0           Embedding_layer_VAR_U3X_BRAKE_FRO
# __________________________________________________________________________________________________
# reshape_170 (Reshape)           (None, 1)            0           Embedding_layer_VAR_T4X_PTO_TRANS
# __________________________________________________________________________________________________
# reshape_171 (Reshape)           (None, 1)            0           Embedding_layer_VAR_UBX_HYDRAULIC
# __________________________________________________________________________________________________
# reshape_172 (Reshape)           (None, 2)            0           Embedding_layer_VAR_4QB_BODYBUILD
# __________________________________________________________________________________________________
# reshape_173 (Reshape)           (None, 2)            0           Embedding_layer_VAR_REX_CRANK_CAS
# __________________________________________________________________________________________________
# reshape_174 (Reshape)           (None, 2)            0           Embedding_layer_VAR_78X_TRANSPORT
# __________________________________________________________________________________________________
# reshape_175 (Reshape)           (None, 1)            0           Embedding_layer_VAR_T2X_TRANSMISS
# __________________________________________________________________________________________________
# reshape_176 (Reshape)           (None, 2)            0           Embedding_layer_VAR_U4X_BRAKE_DRI
# __________________________________________________________________________________________________
# reshape_177 (Reshape)           (None, 4)            0           Embedding_layer_VAR_FVX_FRONT_AXL
# __________________________________________________________________________________________________
# reshape_178 (Reshape)           (None, 2)            0           Embedding_layer_VAR_VWX_COMPRESSO
# __________________________________________________________________________________________________
# reshape_179 (Reshape)           (None, 3)            0           Embedding_layer_VAR_DAX_AXLE_ARRA
# __________________________________________________________________________________________________
# reshape_180 (Reshape)           (None, 1)            0           Embedding_layer_VAR_H1B_TURBO_APP
# __________________________________________________________________________________________________
# reshape_181 (Reshape)           (None, 4)            0           Embedding_layer_VAR_FDX_REAR_AXLE
# __________________________________________________________________________________________________
# reshape_182 (Reshape)           (None, 1)            0           Embedding_layer_VAR_7PX_HYDRAULIC
# __________________________________________________________________________________________________
# reshape_183 (Reshape)           (None, 2)            0           Embedding_layer_VAR_7NA_FRONT_SUS
# __________________________________________________________________________________________________
# reshape_184 (Reshape)           (None, 1)            0           Embedding_layer_VAR_LKX_DRIVER_ST
# __________________________________________________________________________________________________
# reshape_185 (Reshape)           (None, 1)            0           Embedding_layer_VAR_QWX_TURBO[0][
# __________________________________________________________________________________________________
# reshape_186 (Reshape)           (None, 1)            0           Embedding_layer_VAR_FZX_FRONT_AXL
# __________________________________________________________________________________________________
# reshape_187 (Reshape)           (None, 1)            0           Embedding_layer_VAR_V6X_RETARDER[
# __________________________________________________________________________________________________
# reshape_188 (Reshape)           (None, 2)            0           Embedding_layer_VAR_K4C_VEHICLE_U
# __________________________________________________________________________________________________
# reshape_189 (Reshape)           (None, 2)            0           Embedding_layer_VAR_0RA_REGENERAT
# __________________________________________________________________________________________________
# reshape_190 (Reshape)           (None, 1)            0           Embedding_layer_VAR_YKX_FRONT_SUS
# __________________________________________________________________________________________________
# reshape_191 (Reshape)           (None, 1)            0           Embedding_layer_VAR_T3X_PTO_ENGIN
# __________________________________________________________________________________________________
# reshape_192 (Reshape)           (None, 2)            0           Embedding_layer_VAR_PJX_ALTERNATO
# __________________________________________________________________________________________________
# reshape_193 (Reshape)           (None, 2)            0           Embedding_layer_VAR_41X_PARKING_H
# __________________________________________________________________________________________________
# reshape_194 (Reshape)           (None, 1)            0           Embedding_layer_VAR_D7C_WHOLE_VEH
# __________________________________________________________________________________________________
# reshape_195 (Reshape)           (None, 1)            0           Embedding_layer_VAR_5JB_TELEMATIC
# __________________________________________________________________________________________________
# reshape_196 (Reshape)           (None, 4)            0           Embedding_layer_VAR_RWX_TRANSMISS
# __________________________________________________________________________________________________
# reshape_197 (Reshape)           (None, 1)            0           Embedding_layer_VAR_DHX_ROAD_COND
# __________________________________________________________________________________________________
# reshape_198 (Reshape)           (None, 1)            0           Embedding_layer_VAR_2EX_CAB_TILT_
# __________________________________________________________________________________________________
# reshape_199 (Reshape)           (None, 2)            0           Embedding_layer_VAR_D9C_EMISSION_
# __________________________________________________________________________________________________
# reshape_200 (Reshape)           (None, 1)            0           Embedding_layer_VAR_DDX_CHASSIS_T
# __________________________________________________________________________________________________
# reshape_201 (Reshape)           (None, 2)            0           Embedding_layer_VAR_O8A_ENGINE_PT
# __________________________________________________________________________________________________
# reshape_202 (Reshape)           (None, 4)            0           Embedding_layer_VAR_33A_CAB_HEIGH
# __________________________________________________________________________________________________
# reshape_203 (Reshape)           (None, 1)            0           Embedding_layer_VAR_J2A_ACTIVE_ST
# __________________________________________________________________________________________________
# reshape_204 (Reshape)           (None, 2)            0           Embedding_layer_VAR_N9C_ADR_CLASS
# __________________________________________________________________________________________________
# reshape_205 (Reshape)           (None, 2)            0           Embedding_layer_VFE_0001_HORSE_PO
# __________________________________________________________________________________________________
# reshape_206 (Reshape)           (None, 2)            0           Embedding_layer_VFE_0002_GROSS_CO
# __________________________________________________________________________________________________
# reshape_207 (Reshape)           (None, 2)            0           Embedding_layer_VFE_0003_ENGINE_G
# __________________________________________________________________________________________________
# reshape_208 (Reshape)           (None, 6)            0           Embedding_layer_VFE_0004_REAR_AXL
# __________________________________________________________________________________________________
# reshape_209 (Reshape)           (None, 8)            0           Embedding_layer_VFE_0005_REAR_AXL
# __________________________________________________________________________________________________
# reshape_210 (Reshape)           (None, 3)            0           Embedding_layer_VFE_0009_LTVF_TYP
# __________________________________________________________________________________________________
# reshape_211 (Reshape)           (None, 5)            0           Embedding_layer_VFE_0006_VEHICLE_
# __________________________________________________________________________________________________
# reshape_212 (Reshape)           (None, 4)            0           Embedding_layer_VFE_0007_CAB_HEIG
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 157)          0           reshape_143[0][0]
#                                                                  reshape_144[0][0]
#                                                                  reshape_145[0][0]
#                                                                  reshape_146[0][0]
#                                                                  reshape_147[0][0]
#                                                                  reshape_148[0][0]
#                                                                  reshape_149[0][0]
#                                                                  reshape_150[0][0]
#                                                                  reshape_151[0][0]
#                                                                  reshape_152[0][0]
#                                                                  reshape_153[0][0]
#                                                                  reshape_154[0][0]
#                                                                  reshape_155[0][0]
#                                                                  reshape_156[0][0]
#                                                                  reshape_157[0][0]
#                                                                  reshape_158[0][0]
#                                                                  reshape_159[0][0]
#                                                                  reshape_160[0][0]
#                                                                  reshape_161[0][0]
#                                                                  reshape_162[0][0]
#                                                                  reshape_163[0][0]
#                                                                  reshape_164[0][0]
#                                                                  reshape_165[0][0]
#                                                                  reshape_166[0][0]
#                                                                  reshape_167[0][0]
#                                                                  reshape_168[0][0]
#                                                                  reshape_169[0][0]
#                                                                  reshape_170[0][0]
#                                                                  reshape_171[0][0]
#                                                                  reshape_172[0][0]
#                                                                  reshape_173[0][0]
#                                                                  reshape_174[0][0]
#                                                                  reshape_175[0][0]
#                                                                  reshape_176[0][0]
#                                                                  reshape_177[0][0]
#                                                                  reshape_178[0][0]
#                                                                  reshape_179[0][0]
#                                                                  reshape_180[0][0]
#                                                                  reshape_181[0][0]
#                                                                  reshape_182[0][0]
#                                                                  reshape_183[0][0]
#                                                                  reshape_184[0][0]
#                                                                  reshape_185[0][0]
#                                                                  reshape_186[0][0]
#                                                                  reshape_187[0][0]
#                                                                  reshape_188[0][0]
#                                                                  reshape_189[0][0]
#                                                                  reshape_190[0][0]
#                                                                  reshape_191[0][0]
#                                                                  reshape_192[0][0]
#                                                                  reshape_193[0][0]
#                                                                  reshape_194[0][0]
#                                                                  reshape_195[0][0]
#                                                                  reshape_196[0][0]
#                                                                  reshape_197[0][0]
#                                                                  reshape_198[0][0]
#                                                                  reshape_199[0][0]
#                                                                  reshape_200[0][0]
#                                                                  reshape_201[0][0]
#                                                                  reshape_202[0][0]
#                                                                  reshape_203[0][0]
#                                                                  reshape_204[0][0]
#                                                                  reshape_205[0][0]
#                                                                  reshape_206[0][0]
#                                                                  reshape_207[0][0]
#                                                                  reshape_208[0][0]
#                                                                  reshape_209[0][0]
#                                                                  reshape_210[0][0]
#                                                                  reshape_211[0][0]
#                                                                  reshape_212[0][0]
# __________________________________________________________________________________________________
# 1st_Dense_Layer (Dense)         (None, 128)          20224       concatenate_2[0][0]
# ==================================================================================================
# Total params: 21,343
# Trainable params: 21,343
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x = np.array([1,0,1,0]).reshape(4,1)
x
# Out:
# array([[1],
#        [0],
#        [1],
#        [0]])

# %%
model_emb.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-75583b5c8346> in <module>()
# ----> 1 model_emb.predict(x)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1011         max_queue_size=max_queue_size,
#    1012         workers=workers,
# -> 1013         use_multiprocessing=use_multiprocessing)
#    1014
#    1015   def reset_metrics(self):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     496         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
#     497         steps=steps, callbacks=callbacks, max_queue_size=max_queue_size,
# --> 498         workers=workers, use_multiprocessing=use_multiprocessing, **kwargs)
#     499
#     500
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     424           max_queue_size=max_queue_size,
#     425           workers=workers,
# --> 426           use_multiprocessing=use_multiprocessing)
#     427       total_samples = _get_total_number_of_samples(adapter)
#     428       use_sample = total_samples is not None
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in _process_inputs(model, mode, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     644     standardize_function = None
#     645     x, y, sample_weights = standardize(
# --> 646         x, y, sample_weight=sample_weights)
#     647   elif adapter_cls is data_adapter.ListsOfScalarsDataAdapter:
#     648     standardize_function = standardize
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2381         is_dataset=is_dataset,
#    2382         class_weight=class_weight,
# -> 2383         batch_size=batch_size)
#    2384
#    2385   def _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2408           feed_input_shapes,
#    2409           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2410           exception_prefix='input')
#    2411
#    2412     # Get typespecs for the input data and sanitize it if necessary.
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     537                        'for inputs ' + str(names) + ' but instead got the '
#     538                        'following list of ' + str(len(data)) + ' arrays: ' +
# --> 539                        str(data)[:200] + '...')
#     540     elif len(names) > 1:
#     541       raise ValueError('Error when checking model ' + exception_prefix +
#
# ValueError: Error when checking model input: the list of Numpy arrays that you are passing to your model is not the size the model expected. Expected to see 70 array(s), for inputs ['Input_layer_COUNTRY_OF_OPERATION', 'Input_layer_VAR_7MA_FRONT_AXLE_TYPE', 'Input_layer_VAR_DPX_ENGINE_TYPE', 'Input_layer_VAR_T1X_PTO_ENGINE_MOUNTED_REAR', 'Input_layer_VAR_4DX_FRONT_BUMPER', 'Input_layer_VAR_F1X_REAR_AXLE_LOAD', 'Input_layer_VAR_FTX_GROUND_CLEARANCE_FA', 'Input_layer_VAR_CKX_VEHICLE_PROFILE', 'Input_layer_VAR_KTX_ENGINE_EMISSION_CONTROL', 'Input_layer_VAR_3ZB_TRANSMISSION_PTO_TORQUE_CAP', 'Input_layer_VAR_QCX_TOPOGRAPHY', 'Input_layer_VAR_YLX_REAR_SUSPENSION_SYSTEM', 'Input_layer_VAR_DKX_GROSS_COMBINATION_WEIGHT', 'Input_layer_VAR_2RB_BATTERY_MAINTENANCE', 'Input_layer_VAR_FAX_STEERING_WHEEL_POS', 'Input_layer_VAR_2CX_CAB_VERSION', 'Input_layer_VAR_2DX_REAR_CAB_SUSPENSION', 'Input_layer_VAR_GSX_CHASSIS_HEIGHT', 'Input_layer_VAR_FFX_PUSHER_AXLE_FEATURES', 'Input_layer_VAR_5CB_AIR_SUSP_FEATURE_SOFTWARE', 'Input_layer_VAR_2GB_CLUTCHABLE_AIR_COMPRESSOR', 'Input_layer_VAR_5NX_ENGINE_BLOCK_HEATER', 'Input_layer_VAR_TAX_REAR_AXLE_RATIO', 'Input_layer_VAR_A3A_IDLE_SHUTDOWN', 'Input_layer_VAR_2LX_FRONT_CAB_SUSPENSION', 'Input_layer_VAR_RUX_GEAR_SHIFTING_SYSTEM', 'Input_layer_VAR_U3X_BRAKE_FRONT', 'Input_layer_VAR_T4X_PTO_TRANSM_MOUNTED', 'Input_layer_VAR_UBX_HYDRAULIC_PUMP_ENG_MTD', 'Input_layer_VAR_4QB_BODYBUILDER_EL_INTERFCAB_CHAS', 'Input_layer_VAR_REX_CRANK_CASE_VENTILA...
#        [0],
#        [1],
#        [0]])]...

# %%
# creating the embedding model
model = Sequential()

# here
'''
input_dim = Means the vocabulary size of the vector. I.e the max of a possible values the vector can hold. In our test case, then randomint generates value from 0 - 1000. So the vocabulary size is 100
output_dim = The dense vector dimension.
input_length = The dimension of the input vector. For example, the size of the one hot encoding.
'''
# the model will take as input an integer matrix of size (batch, input_length).
# the largest integer (i.e. word index) in the input should be
# no larger than 999 (vocabulary size).
# create the embedding layer
model.add(Embedding(input_dim=2, output_dim=5, input_length=1, name="Embedding_Layer_1"))
# the output of this model : model.output_shape (None, 10, 64) where None is the batch dimension
model.compile(optimizer='rmsprop', loss='mse')

# %%
# check the model summary
model.summary()

# %%
input_array.shape

# %%
output_array = model.predict(x)
output_array

# %%
x1 = input_array[0]
x2 = input_array[1]

# calculating the cosing similarity of two vectors in the orginal space
a_dot = np.dot(x1, x2)
similar = a_dot / (np.linalg.norm(x1) * np.linalg.norm(x2))
similar

# %%
output_array[0].reshape(64,)

# %%
x1 = output_array[0].reshape(64,)
x2 = output_array[1].reshape(64,)

# calculating the cosing similarity of two vectors in the embedding space
a_dot = np.dot(x1, x2)
similar = a_dot / (np.linalg.norm(x1) * np.linalg.norm(x2))
similar
