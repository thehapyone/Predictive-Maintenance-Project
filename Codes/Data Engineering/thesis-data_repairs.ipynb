# %% [markdown]
# # The code is used only for sorting the original repair data.
# It should only be run once.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data_repairs = pd.read_csv("drive/My Drive/Thesis/data/Original Data/PAC_REPAIRS_TRB_20190625_anonymized.csv", sep=';',low_memory=False)
#combined_data = pd.read_csv("drive/My Drive/Colab Notebooks/Thesis/data/combined_data.csv", sep=';', low_memory=False)

# %%
data_repairs.head(4)
# Out:
#    Unnamed: 0 T_CHASSIS    PART_CODE  Record_Count                  RepairDate
# 0           0  O-717289  VO-23083776             1  2019-01-09 00:00:00.000000
# 1           1  O-667412  VO-85020372             1  2018-07-28 00:00:00.000000
# 2           2  O-736946  VO-20781146             1  2017-08-24 00:00:00.000000
# 3           3  O-884007  VO-20784537             1  2019-03-01 00:00:00.000000

# %%
data_repairs.drop(columns="Unnamed: 0", inplace=True)
data_repairs.columns
# Out:
# Index(['T_CHASSIS', 'PART_CODE', 'Record_Count', 'RepairDate'], dtype='object')

# %%
# save combined data as a single csv file
#data_repairs.to_csv("drive/My Drive/Thesis/data/repair_.csv", sep=';', index=False)

# %%
# check all chassis and the number of repairs carried out for the chassis
data_repairs.groupby('T_CHASSIS')['Record_Count'].count()
# Out:
# T_CHASSIS
# N-729040    6
# N-731489    3
# N-731490    2
# N-731586    2
# N-731655    3
#            ..
# Z-949271    1
# Z-949493    1
# Z-951661    1
# Z-953026    1
# Z-956162    1
# Name: Record_Count, Length: 6760, dtype: int64

# %%
# find the total number of unique chassis in the given data
data_repairs['T_CHASSIS'].unique().shape[0]
# Out:
# 6760

# %%
# find the total number of unique chassis in the given data
combined_data['T_CHASSIS'].unique().shape[0]
# Out:
# 6675

# %%
# check the number of unique chassis from repair data we have in the combined data
unique_raw = 0
for r_chassis in data_repairs['T_CHASSIS'].unique():
  if r_chassis in combined_data['T_CHASSIS'].unique():
    unique_raw += 1

print ("Number of unique chassis from repair data in combined data", unique_raw)
# Out:
# Number of unique chassis from repair data in combined data 453

# %%
data_repairs.shape
# Out:
# (13092, 4)

# %%
data_repairs[data_repairs['T_CHASSIS']=='N-759761']
# Out:
#      T_CHASSIS    PART_CODE  Record_Count                  RepairDate
# 4053  N-759761  VO-20789137             1  2018-09-24 00:00:00.000000
# 8259  N-759761  VO-20784537             1  2019-03-23 00:00:00.000000

# %%
df = data_repairs.sort_values(by=['T_CHASSIS', 'RepairDate'], ascending =False)

# %%
df[df['T_CHASSIS']=='N-729040']
# Out:
#       T_CHASSIS    PART_CODE  Record_Count                  RepairDate
# 13086  N-729040  VO-20784537             1  2018-06-11 00:00:00.000000
# 13087  N-729040  VO-20784537             1  2018-02-10 00:00:00.000000
# 13088  N-729040  VO-20784537             1  2017-10-10 00:00:00.000000
# 13089  N-729040  VO-85020372             1  2017-10-10 00:00:00.000000
# 13090  N-729040  VO-85020372             1  2017-06-03 00:00:00.000000
# 13091  N-729040  VO-20784537             1  2017-06-03 00:00:00.000000

# %%
# reset the index
df.reset_index(drop='index', inplace=True)

# %%
# save the new repair data to sorted repairs
df.to_csv("drive/My Drive/Thesis/data/Data_Engineering/Edited_Repair_Data/v1_Sorted_Repairs.csv", sep=',', index=False)
